# %% [markdown]
# # Encoder-Decoder Modelling

# %% [markdown]
# ## Observations and Analysis
#
# - Initially I tried the question by giving all the outputs of the Encoder to the Decoder, but I later realised that it was a form of Pesudo Attention, and we weren't supposed to use it, However with that model I got a score of 2 Marks.
# - Later I tried Three Different approaches, by using a Regular Biderectional Encoder (With Num Layers = 1) and by using a BiDirectional Encoder (With Num Layers = 2) and using a Regular Encoder with 2 layers.
# - In all of the Above I concatenated the outputs and sent it to the Decoder
# - I realised that given the simple enough implementation that we really did not need a very fancy solution (Because the other models did not perform that much better, and required more time to train)
# - The decision between GRU, LSTM and RNN, was made for me by the Checker Script, I got 0.5, 0.5 with the GRU and LSTM and 1 mark with the RNN
# - My Hypothesis is that the LSTM and the GRU learn information that is not really necessary for the given task, that is they overfit the loss

# %%
# Import the Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import wandb

import torch
import torch.nn as nn
import torch.optim as optim

# Initialize the wandb
wandb.login()

input_size = 26
embedding_size = 50
enc_hidden_size = 50
encoding_size = 200
dec_hidden_size = 100
output_size = 26
batch_size = 256
epochs = 1000
learning_rate = 0.001

# Random Seed
seed = 42
np.random.seed(seed)

# Initialize the wandb project
wandb.init(project = 'seq2seq')
# Define the hyperparameters
config = wandb.config
config.learning_rate = learning_rate
config.batch_size = batch_size
config.epochs = epochs
config.input_size = input_size
config.embedding_size = embedding_size
config.enc_hidden_size = enc_hidden_size
config.encoding_size = encoding_size
config.dec_hidden_size = dec_hidden_size
config.output_size = output_size

# Import the Dataset
train_dataset = pd.read_csv('train_data.csv')
eval_dataset = pd.read_csv('eval_data.csv')

# Convert the Dataset to Numpy Array
X_train = train_dataset.iloc[1:, :].values
X_eval = eval_dataset.iloc[1:, :].values

# Each Row, is comprised of 2 columns, the first column is the input, and the second column is the output
X_col = X_train[:, 0]
Y_col = X_train[:, 1]

def numericize(X, Y):
    # Create a dictionary of the alphabet
    alphabet = 'abcdefghijklmnopqrstuvwxyz'
    numeric_dict = {}
    for i in range(len(alphabet)):
        numeric_dict[alphabet[i]] = i

    # Now, each sentence is a 8 letter word, so we need to convert each letter to a number
    X_numeric = []
    Y_numeric = []

    for i in range(len(X)):
        X_numeric.append([numeric_dict[j] for j in X[i]])
        Y_numeric.append([numeric_dict[j] for j in Y[i]])

    return X_numeric, Y_numeric

# Now, for each element in X_Col and Y_Col create embeddings -> each letter is a number in the alphabet
X_numeric, Y_numeric = numericize(X_col, Y_col)

# Convert the X_numeric and Y_numeric to numpy arrays
X_numeric = np.array(X_numeric)
Y_numeric = np.array(Y_numeric)

# Now, we need to convert the X_numeric and Y_numeric to tensors
X_numeric = torch.from_numpy(X_numeric)
Y_numeric = torch.from_numpy(Y_numeric)

# Test Dataset
X_eval_col = X_eval[:, 0]
Y_eval_col = X_eval[:, 1]

# Convert the X_eval_col and Y_eval_col to numeric
X_eval_numeric, Y_eval_numeric = numericize(X_eval_col, Y_eval_col)

# Convert the X_eval_numeric and Y_eval_numeric to numpy arrays
X_eval_numeric = np.array(X_eval_numeric)
Y_eval_numeric = np.array(Y_eval_numeric)

# Convert the X_eval_numeric and Y_eval_numeric to tensors
X_eval_numeric = torch.from_numpy(X_eval_numeric)
Y_eval_numeric = torch.from_numpy(Y_eval_numeric)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: venkata-kesav (iiit_hyd). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/Users/venkatakesavvenna/Sem5/DeepLearning/Assignment_2/Final_Submission/wandb/run-20231026_144855-9gyuyhxl</code>
# Syncing run <strong><a href='https://wandb.ai/iiit_hyd/seq2seq/runs/9gyuyhxl' target="_blank">stilted-bee-68</a></strong> to <a href='https://wandb.ai/iiit_hyd/seq2seq' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/iiit_hyd/seq2seq' target="_blank">https://wandb.ai/iiit_hyd/seq2seq</a>
#  View run at <a href='https://wandb.ai/iiit_hyd/seq2seq/runs/9gyuyhxl' target="_blank">https://wandb.ai/iiit_hyd/seq2seq/runs/9gyuyhxl</a>

# %%
def Model_Output(X, model):
    # Numerize the X
    X, _ = numericize(X, X)
    # Convert the X to a numpy array
    X = np.array(X)
    # Convert the X to a tensor
    X = torch.from_numpy(X)
    # Get the output from the model
    output = model(X)
    # Now, we need to get the output take the argmax of the output along the first dimension and convert it to a set of letters
    output = torch.argmax(output, dim = 2)
    # Now, we need to convert the output to a list of letters
    output = output.tolist()
    # Now, we need to convert the output to a list of letters
    output = [[chr(i + 97) for i in j] for j in output]
    # Join the letters in each list
    output = [''.join(i) for i in output]
    return output


# Write a Custom Loss Function
def Loss_Function(X_eval_col, Y_eval_col, model):
    # Get the output from the model
    output = Model_Output(X_eval_col, model)
    # Now, we need to get the Y_eval_col
    Y_eval_col, _ = numericize(Y_eval_col, Y_eval_col)
    # Now, we need to calculate the loss
    loss = 0
    # For each element in the output, we need to calculate the loss and add it to the loss
    for i in range(len(output)):
        for j in range(len(output[i])):
            if output[i][j] != Y_eval_col[i][j]:
                loss += 0.01

    return loss

# %%
# Now, define the Encoder and Decoder Class
class EncDec(nn.Module):
    def __init__(self, input_size, embedding_size ,enc_hidden_size, encoding_size, dec_hidden_size,output_size, batch_size):
        super(EncDec, self).__init__()
        self.enc_hidden_size = enc_hidden_size
        self.embedding = nn.Embedding(input_size, embedding_size)
        self.dec_hidden_size = dec_hidden_size
        self.batch_size = batch_size
        # Define the Encoder-1 LSTM
        self.encoder = nn.RNN(embedding_size, enc_hidden_size, batch_first = True, bidirectional = True)
        # Define the Decoder-1 LSTM
        self.decoder = nn.RNN(100, dec_hidden_size, batch_first = True)
        # Define the Linear Layer
        self.linear = nn.Linear(100, output_size)
        # Define the Dropout Layer
        self.dropout = nn.Dropout(0.2)

    def forward(self, input):
        # First, we need to convert the input to embeddings
        embedded = self.embedding(input)
        # print("Embedded Shape", embedded.shape)
        enc_hidden1_0 = torch.zeros(2, input.shape[0], self.enc_hidden_size)

        # Now, we need to pass the embeddings through the encoder
        enc_out1, hidden_out1 = self.encoder(embedded, enc_hidden1_0)
        # Get the final hidden state from the encoder
        dec_in = torch.cat((hidden_out1[0], hidden_out1[1]), dim=1)
        dec_in = dec_in.unsqueeze(1)
        # print("Decoder Input Shape", dec_in.shape) # Of Size 256*1*100
        final_in = [] # Of Size 256*1*100
        final_in.append(dec_in) # Of Size 256*1*100
        # print("Final In Shape", final_in[0].shape) # Of Size 256*1*100
        hidden_state = torch.zeros(1, input.shape[0], self.dec_hidden_size) 
        # print("Hidden State Shape", hidden_state.shape) # Of Size 1*256*200
        for i in range(7):
            f_ten = torch.cat(final_in, dim = 1) # Of Size Finally -> 256*8*100
            dec_out, hidden_state = self.decoder(f_ten, hidden_state)
            dec_out = dec_out[:, -1, :]
            final_in.append(dec_out.unsqueeze(1))
        f_ten = torch.cat(final_in, dim = 1)
        final_out = self.linear(f_ten)
        return final_out

# %%
# Now, we need to define the model
model = EncDec(input_size, embedding_size, enc_hidden_size, encoding_size, dec_hidden_size, output_size, batch_size)

# Now, we need to define the loss function and the optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = learning_rate)

# Training loop
for epoch in range(epochs):
    total_loss = 0

    # Mini-batch training
    for i in range(0, len(X_numeric), batch_size):
        optimizer.zero_grad()
        
        # Extract the current batch
        input_batch = X_numeric[i:i+batch_size]
        target_batch = Y_numeric[i:i+batch_size]

        # Forward pass
        output = model(input_batch)

        # Calculate the loss
        loss = criterion(output.view(-1, output_size), target_batch.view(-1))
        total_loss += loss.item()

        # Calculate the accuracy and print
        _, predicted = torch.max(output, dim=2)
        correct = (predicted == target_batch).sum().item()
        accuracy = correct / (batch_size * 8)

        # Backpropagation
        loss.backward()
        optimizer.step()

        print('Epoch: {}, Batch: {}, Loss: {:.6f}, Accuracy: {:.2f}%'.format(epoch, i//batch_size, loss.item(), accuracy * 100))

    if epoch % 10 == 0:
        # Get the Loss
        loss_val = Loss_Function(X_eval_col, Y_eval_col, model)
        # Print the loss
        print('Epoch: ', epoch, ' Validation Loss: ', loss_val)

    # Calculate the loss for the evaluation dataset -> Like the Train Dataset
    eval_loss = criterion(model(X_eval_numeric).view(-1, output_size), Y_eval_numeric.view(-1))

    # Print the average loss for this epoch
    print('Epoch: {}, Loss: {:.6f}'.format(epoch, total_loss / (len(X_numeric) // batch_size)))
    wandb.log({'Epoch': epoch, 'Loss': total_loss / (len(X_numeric) // batch_size), 'Eval Loss': eval_loss.item()})

# Run the Model on a single Evaluation Example
# Out:
# Epoch: 0, Batch: 0, Loss: 3.273032, Accuracy: 4.20%
# Epoch: 0, Batch: 1, Loss: 3.271163, Accuracy: 3.52%
# Epoch: 0, Batch: 2, Loss: 3.263216, Accuracy: 4.35%
# Epoch: 0, Batch: 3, Loss: 3.261011, Accuracy: 4.00%
# Epoch: 0, Batch: 4, Loss: 3.260625, Accuracy: 4.10%
# Epoch: 0, Batch: 5, Loss: 3.255671, Accuracy: 4.35%
# Epoch: 0, Batch: 6, Loss: 3.261335, Accuracy: 4.49%
# Epoch: 0, Batch: 7, Loss: 3.254319, Accuracy: 3.81%
# Epoch: 0, Batch: 8, Loss: 3.255884, Accuracy: 4.98%
# Epoch: 0, Batch: 9, Loss: 3.252102, Accuracy: 5.03%
# Epoch: 0, Batch: 10, Loss: 3.256083, Accuracy: 4.88%
# Epoch: 0, Batch: 11, Loss: 3.251460, Accuracy: 5.18%
# Epoch: 0, Batch: 12, Loss: 3.245968, Accuracy: 4.64%
# Epoch: 0, Batch: 13, Loss: 3.255392, Accuracy: 4.25%
# Epoch: 0, Batch: 14, Loss: 3.248942, Accuracy: 4.20%
# Epoch: 0, Batch: 15, Loss: 3.247919, Accuracy: 5.03%
# Epoch: 0, Batch: 16, Loss: 3.243202, Accuracy: 5.32%
# Epoch: 0, Batch: 17, Loss: 3.246107, Accuracy: 5.42%
# Epoch: 0, Batch: 18, Loss: 3.242838, Accuracy: 5.27%
# Epoch: 0, Batch: 19, Loss: 3.244567, Accuracy: 5.42%
# Epoch: 0, Batch: 20, Loss: 3.237362, Accuracy: 5.96%
# Epoch: 0, Batch: 21, Loss: 3.242802, Accuracy: 4.88%
# Epoch: 0, Batch: 22, Loss: 3.238617, Accuracy: 5.57%
# Epoch: 0, Batch: 23, Loss: 3.237719, Accuracy: 5.57%
# Epoch: 0, Batch: 24, Loss: 3.233818, Accuracy: 6.25%
# Epoch: 0, Batch: 25, Loss: 3.235554, Accuracy: 5.22%
# Epoch: 0, Batch: 26, Loss: 3.229444, Accuracy: 6.40%
# Epoch: 0, Batch: 27, Loss: 3.225075, Accuracy: 2.20%
# Epoch:  0  Validation Loss:  159.91999999999953
# Epoch: 0, Loss: 3.369305
# Epoch: 1, Batch: 0, Loss: 3.208812, Accuracy: 8.25%
# Epoch: 1, Batch: 1, Loss: 3.210851, Accuracy: 7.86%
# Epoch: 1, Batch: 2, Loss: 3.201604, Accuracy: 9.81%
# Epoch: 1, Batch: 3, Loss: 3.206907, Accuracy: 7.76%
# Epoch: 1, Batch: 4, Loss: 3.206645, Accuracy: 7.96%
# Epoch: 1, Batch: 5, Loss: 3.198077, Accuracy: 8.30%
# Epoch: 1, Batch: 6, Loss: 3.204943, Accuracy: 7.37%
# Epoch: 1, Batch: 7, Loss: 3.198566, Accuracy: 8.11%
# Epoch: 1, Batch: 8, Loss: 3.199749, Accuracy: 8.79%
# Epoch: 1, Batch: 9, Loss: 3.196811, Accuracy: 8.54%
# Epoch: 1, Batch: 10, Loss: 3.192961, Accuracy: 8.59%
# Epoch: 1, Batch: 11, Loss: 3.193046, Accuracy: 8.84%
# Epoch: 1, Batch: 12, Loss: 3.184759, Accuracy: 9.72%
# Epoch: 1, Batch: 13, Loss: 3.189480, Accuracy: 9.62%
# Epoch: 1, Batch: 14, Loss: 3.181781, Accuracy: 9.96%
# Epoch: 1, Batch: 15, Loss: 3.174584, Accuracy: 9.08%
# Epoch: 1, Batch: 16, Loss: 3.163376, Accuracy: 9.23%
# Epoch: 1, Batch: 17, Loss: 3.168659, Accuracy: 9.18%
# Epoch: 1, Batch: 18, Loss: 3.156650, Accuracy: 10.21%
# Epoch: 1, Batch: 19, Loss: 3.150738, Accuracy: 10.06%
# Epoch: 1, Batch: 20, Loss: 3.150841, Accuracy: 10.11%
# Epoch: 1, Batch: 21, Loss: 3.149435, Accuracy: 9.67%
# Epoch: 1, Batch: 22, Loss: 3.144546, Accuracy: 9.42%
# Epoch: 1, Batch: 23, Loss: 3.132026, Accuracy: 10.25%
# Epoch: 1, Batch: 24, Loss: 3.138189, Accuracy: 10.50%
# Epoch: 1, Batch: 25, Loss: 3.127811, Accuracy: 11.28%
# Epoch: 1, Batch: 26, Loss: 3.128423, Accuracy: 10.94%
# Epoch: 1, Batch: 27, Loss: 3.084614, Accuracy: 4.59%
# Epoch: 1, Loss: 3.290551
# Epoch: 2, Batch: 0, Loss: 3.101534, Accuracy: 11.28%
# Epoch: 2, Batch: 1, Loss: 3.094271, Accuracy: 11.67%
# Epoch: 2, Batch: 2, Loss: 3.078770, Accuracy: 12.65%
# Epoch: 2, Batch: 3, Loss: 3.086322, Accuracy: 12.74%
# Epoch: 2, Batch: 4, Loss: 3.091186, Accuracy: 10.99%
# Epoch: 2, Batch: 5, Loss: 3.074538, Accuracy: 12.74%
# Epoch: 2, Batch: 6, Loss: 3.079731, Accuracy: 11.43%
# Epoch: 2, Batch: 7, Loss: 3.068594, Accuracy: 12.26%
# Epoch: 2, Batch: 8, Loss: 3.057826, Accuracy: 13.57%
# Epoch: 2, Batch: 9, Loss: 3.068428, Accuracy: 11.87%
# Epoch: 2, Batch: 10, Loss: 3.054948, Accuracy: 13.48%
# Epoch: 2, Batch: 11, Loss: 3.053540, Accuracy: 13.67%
# Epoch: 2, Batch: 12, Loss: 3.047019, Accuracy: 13.77%
# Epoch: 2, Batch: 13, Loss: 3.048628, Accuracy: 13.18%
# Epoch: 2, Batch: 14, Loss: 3.038694, Accuracy: 15.19%
# Epoch: 2, Batch: 15, Loss: 3.039274, Accuracy: 13.23%
# Epoch: 2, Batch: 16, Loss: 3.025651, Accuracy: 14.31%
# Epoch: 2, Batch: 17, Loss: 3.033981, Accuracy: 13.53%
# Epoch: 2, Batch: 18, Loss: 3.013326, Accuracy: 14.50%
# Epoch: 2, Batch: 19, Loss: 3.002346, Accuracy: 14.01%
# Epoch: 2, Batch: 20, Loss: 3.008602, Accuracy: 13.77%
# Epoch: 2, Batch: 21, Loss: 3.005406, Accuracy: 14.31%
# Epoch: 2, Batch: 22, Loss: 3.010873, Accuracy: 13.04%
# Epoch: 2, Batch: 23, Loss: 2.990286, Accuracy: 15.28%
# Epoch: 2, Batch: 24, Loss: 3.000439, Accuracy: 13.96%
# Epoch: 2, Batch: 25, Loss: 2.984553, Accuracy: 14.31%
# Epoch: 2, Batch: 26, Loss: 2.993596, Accuracy: 14.21%
# Epoch: 2, Batch: 27, Loss: 2.932349, Accuracy: 5.57%
# Epoch: 2, Loss: 3.151286
# Epoch: 3, Batch: 0, Loss: 2.974759, Accuracy: 14.84%
# Epoch: 3, Batch: 1, Loss: 2.961108, Accuracy: 15.58%
# Epoch: 3, Batch: 2, Loss: 2.946236, Accuracy: 15.09%
# Epoch: 3, Batch: 3, Loss: 2.950425, Accuracy: 15.77%
# Epoch: 3, Batch: 4, Loss: 2.959137, Accuracy: 14.65%
# Epoch: 3, Batch: 5, Loss: 2.933197, Accuracy: 16.46%
# Epoch: 3, Batch: 6, Loss: 2.949616, Accuracy: 14.11%
# Epoch: 3, Batch: 7, Loss: 2.943216, Accuracy: 15.43%
# Epoch: 3, Batch: 8, Loss: 2.945201, Accuracy: 15.67%
# Epoch: 3, Batch: 9, Loss: 2.945910, Accuracy: 14.65%
# Epoch: 3, Batch: 10, Loss: 2.931684, Accuracy: 15.43%
# Epoch: 3, Batch: 11, Loss: 2.927020, Accuracy: 15.72%
# Epoch: 3, Batch: 12, Loss: 2.923991, Accuracy: 16.26%
# Epoch: 3, Batch: 13, Loss: 2.927983, Accuracy: 16.46%
# Epoch: 3, Batch: 14, Loss: 2.916765, Accuracy: 16.16%
# Epoch: 3, Batch: 15, Loss: 2.917789, Accuracy: 16.06%
# Epoch: 3, Batch: 16, Loss: 2.906197, Accuracy: 15.87%
# Epoch: 3, Batch: 17, Loss: 2.910252, Accuracy: 14.75%
# Epoch: 3, Batch: 18, Loss: 2.888356, Accuracy: 16.89%
# Epoch: 3, Batch: 19, Loss: 2.883951, Accuracy: 16.46%
# Epoch: 3, Batch: 20, Loss: 2.887656, Accuracy: 16.50%
# Epoch: 3, Batch: 21, Loss: 2.887918, Accuracy: 15.87%
# Epoch: 3, Batch: 22, Loss: 2.885262, Accuracy: 16.55%
# Epoch: 3, Batch: 23, Loss: 2.874136, Accuracy: 17.33%
# Epoch: 3, Batch: 24, Loss: 2.877101, Accuracy: 15.87%
# Epoch: 3, Batch: 25, Loss: 2.874578, Accuracy: 16.85%
# Epoch: 3, Batch: 26, Loss: 2.875409, Accuracy: 16.99%
# Epoch: 3, Batch: 27, Loss: 2.812870, Accuracy: 6.01%
# Epoch: 3, Loss: 3.022879
# Epoch: 4, Batch: 0, Loss: 2.858865, Accuracy: 17.33%
# Epoch: 4, Batch: 1, Loss: 2.849390, Accuracy: 17.72%
# Epoch: 4, Batch: 2, Loss: 2.842301, Accuracy: 16.80%
# Epoch: 4, Batch: 3, Loss: 2.845986, Accuracy: 17.82%
# Epoch: 4, Batch: 4, Loss: 2.845777, Accuracy: 16.85%
# Epoch: 4, Batch: 5, Loss: 2.832591, Accuracy: 17.68%
# Epoch: 4, Batch: 6, Loss: 2.842299, Accuracy: 15.48%
# Epoch: 4, Batch: 7, Loss: 2.839992, Accuracy: 16.85%
# Epoch: 4, Batch: 8, Loss: 2.847259, Accuracy: 17.19%
# Epoch: 4, Batch: 9, Loss: 2.838887, Accuracy: 16.60%
# Epoch: 4, Batch: 10, Loss: 2.831052, Accuracy: 17.68%
# Epoch: 4, Batch: 11, Loss: 2.826626, Accuracy: 17.43%
# Epoch: 4, Batch: 12, Loss: 2.821119, Accuracy: 17.19%
# Epoch: 4, Batch: 13, Loss: 2.834746, Accuracy: 16.70%
# Epoch: 4, Batch: 14, Loss: 2.819930, Accuracy: 16.94%
# Epoch: 4, Batch: 15, Loss: 2.822790, Accuracy: 16.50%
# Epoch: 4, Batch: 16, Loss: 2.809970, Accuracy: 16.46%
# Epoch: 4, Batch: 17, Loss: 2.816198, Accuracy: 14.55%
# Epoch: 4, Batch: 18, Loss: 2.795022, Accuracy: 16.85%
# Epoch: 4, Batch: 19, Loss: 2.792639, Accuracy: 17.48%
# Epoch: 4, Batch: 20, Loss: 2.795693, Accuracy: 16.94%
# Epoch: 4, Batch: 21, Loss: 2.795862, Accuracy: 16.26%
# Epoch: 4, Batch: 22, Loss: 2.792797, Accuracy: 17.48%
# Epoch: 4, Batch: 23, Loss: 2.793975, Accuracy: 17.58%
# Epoch: 4, Batch: 24, Loss: 2.789666, Accuracy: 15.82%
# Epoch: 4, Batch: 25, Loss: 2.790090, Accuracy: 18.07%
# Epoch: 4, Batch: 26, Loss: 2.787066, Accuracy: 17.63%
# Epoch: 4, Batch: 27, Loss: 2.715756, Accuracy: 6.40%
# Epoch: 4, Loss: 2.921272
# Epoch: 5, Batch: 0, Loss: 2.775423, Accuracy: 18.07%
# Epoch: 5, Batch: 1, Loss: 2.774428, Accuracy: 18.16%
# Epoch: 5, Batch: 2, Loss: 2.768902, Accuracy: 17.24%
# Epoch: 5, Batch: 3, Loss: 2.769778, Accuracy: 17.33%
# Epoch: 5, Batch: 4, Loss: 2.769989, Accuracy: 17.92%
# Epoch: 5, Batch: 5, Loss: 2.763688, Accuracy: 18.70%
# Epoch: 5, Batch: 6, Loss: 2.771065, Accuracy: 17.29%
# Epoch: 5, Batch: 7, Loss: 2.771485, Accuracy: 16.65%
# Epoch: 5, Batch: 8, Loss: 2.771421, Accuracy: 17.63%
# Epoch: 5, Batch: 9, Loss: 2.763163, Accuracy: 16.55%
# Epoch: 5, Batch: 10, Loss: 2.761583, Accuracy: 17.38%
# Epoch: 5, Batch: 11, Loss: 2.757351, Accuracy: 17.77%
# Epoch: 5, Batch: 12, Loss: 2.752379, Accuracy: 17.33%
# Epoch: 5, Batch: 13, Loss: 2.769402, Accuracy: 16.94%
# Epoch: 5, Batch: 14, Loss: 2.751717, Accuracy: 17.48%
# Epoch: 5, Batch: 15, Loss: 2.758329, Accuracy: 16.60%
# Epoch: 5, Batch: 16, Loss: 2.745966, Accuracy: 16.89%
# Epoch: 5, Batch: 17, Loss: 2.754472, Accuracy: 15.77%
# Epoch: 5, Batch: 18, Loss: 2.734273, Accuracy: 17.72%
# Epoch: 5, Batch: 19, Loss: 2.731940, Accuracy: 17.97%
# Epoch: 5, Batch: 20, Loss: 2.736641, Accuracy: 17.04%
# Epoch: 5, Batch: 21, Loss: 2.735193, Accuracy: 16.46%
# Epoch: 5, Batch: 22, Loss: 2.732900, Accuracy: 17.48%
# Epoch: 5, Batch: 23, Loss: 2.742717, Accuracy: 17.58%
# Epoch: 5, Batch: 24, Loss: 2.731191, Accuracy: 16.46%
# Epoch: 5, Batch: 25, Loss: 2.734239, Accuracy: 17.63%
# Epoch: 5, Batch: 26, Loss: 2.728693, Accuracy: 18.02%
# Epoch: 5, Batch: 27, Loss: 2.644840, Accuracy: 6.98%
# Epoch: 5, Loss: 2.851969
# Epoch: 6, Batch: 0, Loss: 2.718064, Accuracy: 17.92%
# Epoch: 6, Batch: 1, Loss: 2.724414, Accuracy: 18.60%
# Epoch: 6, Batch: 2, Loss: 2.719305, Accuracy: 17.24%
# Epoch: 6, Batch: 3, Loss: 2.718048, Accuracy: 17.82%
# Epoch: 6, Batch: 4, Loss: 2.719945, Accuracy: 18.55%
# Epoch: 6, Batch: 5, Loss: 2.714707, Accuracy: 18.07%
# Epoch: 6, Batch: 6, Loss: 2.722817, Accuracy: 17.53%
# Epoch: 6, Batch: 7, Loss: 2.722113, Accuracy: 17.33%
# Epoch: 6, Batch: 8, Loss: 2.720333, Accuracy: 18.36%
# Epoch: 6, Batch: 9, Loss: 2.713373, Accuracy: 17.19%
# Epoch: 6, Batch: 10, Loss: 2.714701, Accuracy: 16.85%
# Epoch: 6, Batch: 11, Loss: 2.709232, Accuracy: 18.99%
# Epoch: 6, Batch: 12, Loss: 2.706147, Accuracy: 17.58%
# Epoch: 6, Batch: 13, Loss: 2.723214, Accuracy: 16.85%
# Epoch: 6, Batch: 14, Loss: 2.702544, Accuracy: 18.46%
# Epoch: 6, Batch: 15, Loss: 2.712276, Accuracy: 17.33%
# Epoch: 6, Batch: 16, Loss: 2.701194, Accuracy: 17.82%
# Epoch: 6, Batch: 17, Loss: 2.711657, Accuracy: 16.26%
# Epoch: 6, Batch: 18, Loss: 2.693493, Accuracy: 17.82%
# Epoch: 6, Batch: 19, Loss: 2.692365, Accuracy: 17.92%
# Epoch: 6, Batch: 20, Loss: 2.697265, Accuracy: 17.68%
# Epoch: 6, Batch: 21, Loss: 2.695960, Accuracy: 16.70%
# Epoch: 6, Batch: 22, Loss: 2.692187, Accuracy: 17.92%
# Epoch: 6, Batch: 23, Loss: 2.705140, Accuracy: 17.63%
# Epoch: 6, Batch: 24, Loss: 2.692193, Accuracy: 17.38%
# Epoch: 6, Batch: 25, Loss: 2.696205, Accuracy: 17.33%
# Epoch: 6, Batch: 26, Loss: 2.688272, Accuracy: 17.68%
# Epoch: 6, Batch: 27, Loss: 2.592970, Accuracy: 7.28%
# Epoch: 6, Loss: 2.804449
# Epoch: 7, Batch: 0, Loss: 2.679390, Accuracy: 17.87%
# Epoch: 7, Batch: 1, Loss: 2.689420, Accuracy: 18.51%
# Epoch: 7, Batch: 2, Loss: 2.684260, Accuracy: 17.33%
# Epoch: 7, Batch: 3, Loss: 2.681632, Accuracy: 18.55%
# Epoch: 7, Batch: 4, Loss: 2.685853, Accuracy: 18.90%
# Epoch: 7, Batch: 5, Loss: 2.679515, Accuracy: 18.95%
# Epoch: 7, Batch: 6, Loss: 2.688798, Accuracy: 17.82%
# Epoch: 7, Batch: 7, Loss: 2.687662, Accuracy: 17.29%
# Epoch: 7, Batch: 8, Loss: 2.684757, Accuracy: 19.19%
# Epoch: 7, Batch: 9, Loss: 2.681339, Accuracy: 17.97%
# Epoch: 7, Batch: 10, Loss: 2.682184, Accuracy: 16.94%
# Epoch: 7, Batch: 11, Loss: 2.675279, Accuracy: 18.75%
# Epoch: 7, Batch: 12, Loss: 2.674948, Accuracy: 18.65%
# Epoch: 7, Batch: 13, Loss: 2.689544, Accuracy: 16.80%
# Epoch: 7, Batch: 14, Loss: 2.668176, Accuracy: 19.43%
# Epoch: 7, Batch: 15, Loss: 2.678926, Accuracy: 17.77%
# Epoch: 7, Batch: 16, Loss: 2.669968, Accuracy: 18.21%
# Epoch: 7, Batch: 17, Loss: 2.679778, Accuracy: 16.99%
# Epoch: 7, Batch: 18, Loss: 2.664128, Accuracy: 17.77%
# Epoch: 7, Batch: 19, Loss: 2.662950, Accuracy: 18.26%
# Epoch: 7, Batch: 20, Loss: 2.668751, Accuracy: 18.21%
# Epoch: 7, Batch: 21, Loss: 2.667830, Accuracy: 17.77%
# Epoch: 7, Batch: 22, Loss: 2.662772, Accuracy: 18.21%
# Epoch: 7, Batch: 23, Loss: 2.676102, Accuracy: 17.29%
# Epoch: 7, Batch: 24, Loss: 2.665576, Accuracy: 18.12%
# Epoch: 7, Batch: 25, Loss: 2.669266, Accuracy: 17.72%
# Epoch: 7, Batch: 26, Loss: 2.658756, Accuracy: 18.07%
# Epoch: 7, Batch: 27, Loss: 2.551857, Accuracy: 8.40%
# Epoch: 7, Loss: 2.770719
# Epoch: 8, Batch: 0, Loss: 2.652482, Accuracy: 17.63%
# Epoch: 8, Batch: 1, Loss: 2.663145, Accuracy: 18.75%
# Epoch: 8, Batch: 2, Loss: 2.657706, Accuracy: 17.29%
# Epoch: 8, Batch: 3, Loss: 2.653974, Accuracy: 18.70%
# Epoch: 8, Batch: 4, Loss: 2.659630, Accuracy: 19.19%
# Epoch: 8, Batch: 5, Loss: 2.651868, Accuracy: 19.48%
# Epoch: 8, Batch: 6, Loss: 2.662291, Accuracy: 17.82%
# Epoch: 8, Batch: 7, Loss: 2.660541, Accuracy: 17.29%
# Epoch: 8, Batch: 8, Loss: 2.657797, Accuracy: 20.02%
# Epoch: 8, Batch: 9, Loss: 2.658565, Accuracy: 17.77%
# Epoch: 8, Batch: 10, Loss: 2.658018, Accuracy: 17.48%
# Epoch: 8, Batch: 11, Loss: 2.649891, Accuracy: 19.53%
# Epoch: 8, Batch: 12, Loss: 2.651961, Accuracy: 19.04%
# Epoch: 8, Batch: 13, Loss: 2.662837, Accuracy: 17.48%
# Epoch: 8, Batch: 14, Loss: 2.642280, Accuracy: 19.58%
# Epoch: 8, Batch: 15, Loss: 2.653829, Accuracy: 18.46%
# Epoch: 8, Batch: 16, Loss: 2.646369, Accuracy: 18.51%
# Epoch: 8, Batch: 17, Loss: 2.655632, Accuracy: 16.99%
# Epoch: 8, Batch: 18, Loss: 2.642559, Accuracy: 17.87%
# Epoch: 8, Batch: 19, Loss: 2.639739, Accuracy: 18.85%
# Epoch: 8, Batch: 20, Loss: 2.645405, Accuracy: 18.55%
# Epoch: 8, Batch: 21, Loss: 2.644426, Accuracy: 18.21%
# Epoch: 8, Batch: 22, Loss: 2.639098, Accuracy: 18.65%
# Epoch: 8, Batch: 23, Loss: 2.653195, Accuracy: 17.24%
# Epoch: 8, Batch: 24, Loss: 2.645283, Accuracy: 18.75%
# Epoch: 8, Batch: 25, Loss: 2.648057, Accuracy: 17.48%
# Epoch: 8, Batch: 26, Loss: 2.635317, Accuracy: 18.99%
# Epoch: 8, Batch: 27, Loss: 2.515887, Accuracy: 8.84%
# Epoch: 8, Loss: 2.744733
# Epoch: 9, Batch: 0, Loss: 2.631280, Accuracy: 18.21%
# Epoch: 9, Batch: 1, Loss: 2.641417, Accuracy: 18.65%
# Epoch: 9, Batch: 2, Loss: 2.636579, Accuracy: 18.16%
# Epoch: 9, Batch: 3, Loss: 2.631449, Accuracy: 19.09%
# Epoch: 9, Batch: 4, Loss: 2.638257, Accuracy: 19.43%
# Epoch: 9, Batch: 5, Loss: 2.628366, Accuracy: 19.87%
# Epoch: 9, Batch: 6, Loss: 2.640553, Accuracy: 18.26%
# Epoch: 9, Batch: 7, Loss: 2.637641, Accuracy: 18.70%
# Epoch: 9, Batch: 8, Loss: 2.635639, Accuracy: 19.92%
# Epoch: 9, Batch: 9, Loss: 2.639357, Accuracy: 18.21%
# Epoch: 9, Batch: 10, Loss: 2.638381, Accuracy: 17.82%
# Epoch: 9, Batch: 11, Loss: 2.629784, Accuracy: 19.58%
# Epoch: 9, Batch: 12, Loss: 2.632996, Accuracy: 19.97%
# Epoch: 9, Batch: 13, Loss: 2.639972, Accuracy: 17.82%
# Epoch: 9, Batch: 14, Loss: 2.620375, Accuracy: 19.78%
# Epoch: 9, Batch: 15, Loss: 2.633255, Accuracy: 18.36%
# Epoch: 9, Batch: 16, Loss: 2.626254, Accuracy: 19.24%
# Epoch: 9, Batch: 17, Loss: 2.636346, Accuracy: 17.58%
# Epoch: 9, Batch: 18, Loss: 2.625950, Accuracy: 18.31%
# Epoch: 9, Batch: 19, Loss: 2.621192, Accuracy: 18.99%
# Epoch: 9, Batch: 20, Loss: 2.624954, Accuracy: 18.26%
# Epoch: 9, Batch: 21, Loss: 2.623465, Accuracy: 18.16%
# Epoch: 9, Batch: 22, Loss: 2.618202, Accuracy: 18.99%
# Epoch: 9, Batch: 23, Loss: 2.634097, Accuracy: 18.31%
# Epoch: 9, Batch: 24, Loss: 2.627925, Accuracy: 19.73%
# Epoch: 9, Batch: 25, Loss: 2.629767, Accuracy: 17.63%
# Epoch: 9, Batch: 26, Loss: 2.615528, Accuracy: 19.63%
# Epoch: 9, Batch: 27, Loss: 2.482877, Accuracy: 9.18%
# Epoch: 9, Loss: 2.723032
# Epoch: 10, Batch: 0, Loss: 2.612103, Accuracy: 18.80%
# Epoch: 10, Batch: 1, Loss: 2.621861, Accuracy: 18.99%
# Epoch: 10, Batch: 2, Loss: 2.618182, Accuracy: 19.14%
# Epoch: 10, Batch: 3, Loss: 2.611852, Accuracy: 19.58%
# Epoch: 10, Batch: 4, Loss: 2.619513, Accuracy: 19.63%
# Epoch: 10, Batch: 5, Loss: 2.607428, Accuracy: 20.41%
# Epoch: 10, Batch: 6, Loss: 2.621999, Accuracy: 18.21%
# Epoch: 10, Batch: 7, Loss: 2.617334, Accuracy: 18.99%
# Epoch: 10, Batch: 8, Loss: 2.616613, Accuracy: 20.02%
# Epoch: 10, Batch: 9, Loss: 2.621117, Accuracy: 18.41%
# Epoch: 10, Batch: 10, Loss: 2.620912, Accuracy: 18.41%
# Epoch: 10, Batch: 11, Loss: 2.612700, Accuracy: 19.43%
# Epoch: 10, Batch: 12, Loss: 2.616336, Accuracy: 19.87%
# Epoch: 10, Batch: 13, Loss: 2.619734, Accuracy: 18.02%
# Epoch: 10, Batch: 14, Loss: 2.600488, Accuracy: 20.02%
# Epoch: 10, Batch: 15, Loss: 2.615175, Accuracy: 18.90%
# Epoch: 10, Batch: 16, Loss: 2.607615, Accuracy: 19.97%
# Epoch: 10, Batch: 17, Loss: 2.619079, Accuracy: 18.41%
# Epoch: 10, Batch: 18, Loss: 2.611608, Accuracy: 18.31%
# Epoch: 10, Batch: 19, Loss: 2.605317, Accuracy: 19.87%
# Epoch: 10, Batch: 20, Loss: 2.606838, Accuracy: 18.70%
# Epoch: 10, Batch: 21, Loss: 2.604020, Accuracy: 19.14%
# Epoch: 10, Batch: 22, Loss: 2.599167, Accuracy: 19.82%
# Epoch: 10, Batch: 23, Loss: 2.617079, Accuracy: 18.90%
# Epoch: 10, Batch: 24, Loss: 2.611724, Accuracy: 19.53%
# Epoch: 10, Batch: 25, Loss: 2.612972, Accuracy: 17.77%
# Epoch: 10, Batch: 26, Loss: 2.597598, Accuracy: 19.73%
# Epoch: 10, Batch: 27, Loss: 2.451244, Accuracy: 9.47%
# Epoch:  10  Validation Loss:  159.91999999999953
# Epoch: 10, Loss: 2.703615
# Epoch: 11, Batch: 0, Loss: 2.593864, Accuracy: 19.34%
# Epoch: 11, Batch: 1, Loss: 2.604006, Accuracy: 18.95%
# Epoch: 11, Batch: 2, Loss: 2.601107, Accuracy: 19.19%
# Epoch: 11, Batch: 3, Loss: 2.594069, Accuracy: 20.02%
# Epoch: 11, Batch: 4, Loss: 2.601707, Accuracy: 20.12%
# Epoch: 11, Batch: 5, Loss: 2.588237, Accuracy: 20.07%
# Epoch: 11, Batch: 6, Loss: 2.605083, Accuracy: 18.75%
# Epoch: 11, Batch: 7, Loss: 2.598332, Accuracy: 20.17%
# Epoch: 11, Batch: 8, Loss: 2.599479, Accuracy: 21.00%
# Epoch: 11, Batch: 9, Loss: 2.603254, Accuracy: 18.55%
# Epoch: 11, Batch: 10, Loss: 2.604256, Accuracy: 19.09%
# Epoch: 11, Batch: 11, Loss: 2.596884, Accuracy: 20.46%
# Epoch: 11, Batch: 12, Loss: 2.600684, Accuracy: 19.78%
# Epoch: 11, Batch: 13, Loss: 2.601181, Accuracy: 18.51%
# Epoch: 11, Batch: 14, Loss: 2.582134, Accuracy: 20.70%
# Epoch: 11, Batch: 15, Loss: 2.598601, Accuracy: 18.99%
# Epoch: 11, Batch: 16, Loss: 2.589858, Accuracy: 20.46%
# Epoch: 11, Batch: 17, Loss: 2.602684, Accuracy: 18.65%
# Epoch: 11, Batch: 18, Loss: 2.597790, Accuracy: 18.41%
# Epoch: 11, Batch: 19, Loss: 2.590281, Accuracy: 20.02%
# Epoch: 11, Batch: 20, Loss: 2.590066, Accuracy: 19.19%
# Epoch: 11, Batch: 21, Loss: 2.585688, Accuracy: 19.29%
# Epoch: 11, Batch: 22, Loss: 2.581682, Accuracy: 20.07%
# Epoch: 11, Batch: 23, Loss: 2.601243, Accuracy: 19.43%
# Epoch: 11, Batch: 24, Loss: 2.595738, Accuracy: 19.87%
# Epoch: 11, Batch: 25, Loss: 2.597203, Accuracy: 18.80%
# Epoch: 11, Batch: 26, Loss: 2.580706, Accuracy: 19.87%
# Epoch: 11, Batch: 27, Loss: 2.419925, Accuracy: 9.52%
# Epoch: 11, Loss: 2.685398
# Epoch: 12, Batch: 0, Loss: 2.576583, Accuracy: 19.87%
# Epoch: 12, Batch: 1, Loss: 2.587770, Accuracy: 18.95%
# Epoch: 12, Batch: 2, Loss: 2.585014, Accuracy: 20.21%
# Epoch: 12, Batch: 3, Loss: 2.577380, Accuracy: 20.80%
# Epoch: 12, Batch: 4, Loss: 2.584141, Accuracy: 20.31%
# Epoch: 12, Batch: 5, Loss: 2.570119, Accuracy: 20.85%
# Epoch: 12, Batch: 6, Loss: 2.588810, Accuracy: 19.34%
# Epoch: 12, Batch: 7, Loss: 2.580141, Accuracy: 20.12%
# Epoch: 12, Batch: 8, Loss: 2.583392, Accuracy: 20.95%
# Epoch: 12, Batch: 9, Loss: 2.585886, Accuracy: 18.85%
# Epoch: 12, Batch: 10, Loss: 2.587962, Accuracy: 19.43%
# Epoch: 12, Batch: 11, Loss: 2.581769, Accuracy: 20.17%
# Epoch: 12, Batch: 12, Loss: 2.585411, Accuracy: 20.17%
# Epoch: 12, Batch: 13, Loss: 2.583576, Accuracy: 18.46%
# Epoch: 12, Batch: 14, Loss: 2.565148, Accuracy: 21.00%
# Epoch: 12, Batch: 15, Loss: 2.583072, Accuracy: 19.53%
# Epoch: 12, Batch: 16, Loss: 2.572751, Accuracy: 20.61%
# Epoch: 12, Batch: 17, Loss: 2.586799, Accuracy: 18.85%
# Epoch: 12, Batch: 18, Loss: 2.583938, Accuracy: 18.51%
# Epoch: 12, Batch: 19, Loss: 2.575268, Accuracy: 20.17%
# Epoch: 12, Batch: 20, Loss: 2.574021, Accuracy: 19.58%
# Epoch: 12, Batch: 21, Loss: 2.568397, Accuracy: 19.63%
# Epoch: 12, Batch: 22, Loss: 2.565234, Accuracy: 20.17%
# Epoch: 12, Batch: 23, Loss: 2.585754, Accuracy: 19.73%
# Epoch: 12, Batch: 24, Loss: 2.579485, Accuracy: 20.21%
# Epoch: 12, Batch: 25, Loss: 2.582466, Accuracy: 19.43%
# Epoch: 12, Batch: 26, Loss: 2.564582, Accuracy: 20.75%
# Epoch: 12, Batch: 27, Loss: 2.389103, Accuracy: 9.72%
# Epoch: 12, Loss: 2.667925
# Epoch: 13, Batch: 0, Loss: 2.560171, Accuracy: 20.02%
# Epoch: 13, Batch: 1, Loss: 2.572498, Accuracy: 19.19%
# Epoch: 13, Batch: 2, Loss: 2.569576, Accuracy: 20.90%
# Epoch: 13, Batch: 3, Loss: 2.561380, Accuracy: 21.00%
# Epoch: 13, Batch: 4, Loss: 2.566837, Accuracy: 21.00%
# Epoch: 13, Batch: 5, Loss: 2.552579, Accuracy: 21.00%
# Epoch: 13, Batch: 6, Loss: 2.572927, Accuracy: 19.53%
# Epoch: 13, Batch: 7, Loss: 2.562889, Accuracy: 21.29%
# Epoch: 13, Batch: 8, Loss: 2.567946, Accuracy: 20.85%
# Epoch: 13, Batch: 9, Loss: 2.569256, Accuracy: 19.87%
# Epoch: 13, Batch: 10, Loss: 2.571900, Accuracy: 19.29%
# Epoch: 13, Batch: 11, Loss: 2.567557, Accuracy: 20.51%
# Epoch: 13, Batch: 12, Loss: 2.570527, Accuracy: 20.21%
# Epoch: 13, Batch: 13, Loss: 2.566680, Accuracy: 18.70%
# Epoch: 13, Batch: 14, Loss: 2.549429, Accuracy: 21.34%
# Epoch: 13, Batch: 15, Loss: 2.568443, Accuracy: 19.58%
# Epoch: 13, Batch: 16, Loss: 2.556093, Accuracy: 21.00%
# Epoch: 13, Batch: 17, Loss: 2.570867, Accuracy: 19.68%
# Epoch: 13, Batch: 18, Loss: 2.569913, Accuracy: 18.80%
# Epoch: 13, Batch: 19, Loss: 2.560325, Accuracy: 20.26%
# Epoch: 13, Batch: 20, Loss: 2.558568, Accuracy: 19.73%
# Epoch: 13, Batch: 21, Loss: 2.551843, Accuracy: 19.53%
# Epoch: 13, Batch: 22, Loss: 2.549453, Accuracy: 20.61%
# Epoch: 13, Batch: 23, Loss: 2.570312, Accuracy: 20.07%
# Epoch: 13, Batch: 24, Loss: 2.563108, Accuracy: 20.31%
# Epoch: 13, Batch: 25, Loss: 2.568692, Accuracy: 19.19%
# Epoch: 13, Batch: 26, Loss: 2.549015, Accuracy: 20.70%
# Epoch: 13, Batch: 27, Loss: 2.359262, Accuracy: 10.01%
# Epoch: 13, Loss: 2.651039
# Epoch: 14, Batch: 0, Loss: 2.544180, Accuracy: 20.90%
# Epoch: 14, Batch: 1, Loss: 2.557634, Accuracy: 19.34%
# Epoch: 14, Batch: 2, Loss: 2.554621, Accuracy: 20.95%
# Epoch: 14, Batch: 3, Loss: 2.546046, Accuracy: 21.24%
# Epoch: 14, Batch: 4, Loss: 2.549981, Accuracy: 21.24%
# Epoch: 14, Batch: 5, Loss: 2.535644, Accuracy: 21.44%
# Epoch: 14, Batch: 6, Loss: 2.557211, Accuracy: 19.73%
# Epoch: 14, Batch: 7, Loss: 2.546555, Accuracy: 21.29%
# Epoch: 14, Batch: 8, Loss: 2.552891, Accuracy: 21.00%
# Epoch: 14, Batch: 9, Loss: 2.553713, Accuracy: 20.07%
# Epoch: 14, Batch: 10, Loss: 2.556148, Accuracy: 19.73%
# Epoch: 14, Batch: 11, Loss: 2.554302, Accuracy: 20.80%
# Epoch: 14, Batch: 12, Loss: 2.556107, Accuracy: 19.92%
# Epoch: 14, Batch: 13, Loss: 2.550559, Accuracy: 19.53%
# Epoch: 14, Batch: 14, Loss: 2.534883, Accuracy: 21.88%
# Epoch: 14, Batch: 15, Loss: 2.554635, Accuracy: 19.82%
# Epoch: 14, Batch: 16, Loss: 2.539878, Accuracy: 21.24%
# Epoch: 14, Batch: 17, Loss: 2.554600, Accuracy: 20.51%
# Epoch: 14, Batch: 18, Loss: 2.555870, Accuracy: 18.75%
# Epoch: 14, Batch: 19, Loss: 2.545514, Accuracy: 20.46%
# Epoch: 14, Batch: 20, Loss: 2.543677, Accuracy: 20.36%
# Epoch: 14, Batch: 21, Loss: 2.535535, Accuracy: 20.26%
# Epoch: 14, Batch: 22, Loss: 2.534217, Accuracy: 21.44%
# Epoch: 14, Batch: 23, Loss: 2.555234, Accuracy: 20.41%
# Epoch: 14, Batch: 24, Loss: 2.546956, Accuracy: 21.29%
# Epoch: 14, Batch: 25, Loss: 2.555501, Accuracy: 19.38%
# Epoch: 14, Batch: 26, Loss: 2.533736, Accuracy: 20.85%
# Epoch: 14, Batch: 27, Loss: 2.330413, Accuracy: 10.30%
# Epoch: 14, Loss: 2.634676
# Epoch: 15, Batch: 0, Loss: 2.528326, Accuracy: 20.80%
# Epoch: 15, Batch: 1, Loss: 2.542855, Accuracy: 19.82%
# Epoch: 15, Batch: 2, Loss: 2.540224, Accuracy: 21.58%
# Epoch: 15, Batch: 3, Loss: 2.531197, Accuracy: 21.34%
# Epoch: 15, Batch: 4, Loss: 2.533624, Accuracy: 21.14%
# Epoch: 15, Batch: 5, Loss: 2.519534, Accuracy: 21.73%
# Epoch: 15, Batch: 6, Loss: 2.541598, Accuracy: 20.12%
# Epoch: 15, Batch: 7, Loss: 2.530910, Accuracy: 21.92%
# Epoch: 15, Batch: 8, Loss: 2.538105, Accuracy: 21.63%
# Epoch: 15, Batch: 9, Loss: 2.539155, Accuracy: 20.65%
# Epoch: 15, Batch: 10, Loss: 2.540659, Accuracy: 19.97%
# Epoch: 15, Batch: 11, Loss: 2.541689, Accuracy: 20.46%
# Epoch: 15, Batch: 12, Loss: 2.542144, Accuracy: 20.31%
# Epoch: 15, Batch: 13, Loss: 2.535124, Accuracy: 19.73%
# Epoch: 15, Batch: 14, Loss: 2.521114, Accuracy: 22.02%
# Epoch: 15, Batch: 15, Loss: 2.541513, Accuracy: 20.12%
# Epoch: 15, Batch: 16, Loss: 2.524304, Accuracy: 21.73%
# Epoch: 15, Batch: 17, Loss: 2.538185, Accuracy: 20.90%
# Epoch: 15, Batch: 18, Loss: 2.542234, Accuracy: 19.34%
# Epoch: 15, Batch: 19, Loss: 2.530711, Accuracy: 21.00%
# Epoch: 15, Batch: 20, Loss: 2.529367, Accuracy: 20.65%
# Epoch: 15, Batch: 21, Loss: 2.519397, Accuracy: 21.24%
# Epoch: 15, Batch: 22, Loss: 2.519555, Accuracy: 21.83%
# Epoch: 15, Batch: 23, Loss: 2.540689, Accuracy: 20.90%
# Epoch: 15, Batch: 24, Loss: 2.531324, Accuracy: 21.58%
# Epoch: 15, Batch: 25, Loss: 2.542426, Accuracy: 19.73%
# Epoch: 15, Batch: 26, Loss: 2.518608, Accuracy: 20.85%
# Epoch: 15, Batch: 27, Loss: 2.302331, Accuracy: 10.79%
# Epoch: 15, Loss: 2.618774
# Epoch: 16, Batch: 0, Loss: 2.512794, Accuracy: 20.85%
# Epoch: 16, Batch: 1, Loss: 2.527906, Accuracy: 20.70%
# Epoch: 16, Batch: 2, Loss: 2.526423, Accuracy: 21.39%
# Epoch: 16, Batch: 3, Loss: 2.516739, Accuracy: 21.83%
# Epoch: 16, Batch: 4, Loss: 2.517833, Accuracy: 21.09%
# Epoch: 16, Batch: 5, Loss: 2.504339, Accuracy: 21.29%
# Epoch: 16, Batch: 6, Loss: 2.526260, Accuracy: 20.51%
# Epoch: 16, Batch: 7, Loss: 2.515832, Accuracy: 21.88%
# Epoch: 16, Batch: 8, Loss: 2.523630, Accuracy: 21.92%
# Epoch: 16, Batch: 9, Loss: 2.525174, Accuracy: 21.44%
# Epoch: 16, Batch: 10, Loss: 2.525244, Accuracy: 20.61%
# Epoch: 16, Batch: 11, Loss: 2.529249, Accuracy: 20.61%
# Epoch: 16, Batch: 12, Loss: 2.528805, Accuracy: 21.09%
# Epoch: 16, Batch: 13, Loss: 2.520298, Accuracy: 20.61%
# Epoch: 16, Batch: 14, Loss: 2.507849, Accuracy: 22.36%
# Epoch: 16, Batch: 15, Loss: 2.528691, Accuracy: 20.26%
# Epoch: 16, Batch: 16, Loss: 2.509391, Accuracy: 21.73%
# Epoch: 16, Batch: 17, Loss: 2.521910, Accuracy: 21.58%
# Epoch: 16, Batch: 18, Loss: 2.529176, Accuracy: 20.31%
# Epoch: 16, Batch: 19, Loss: 2.515779, Accuracy: 21.14%
# Epoch: 16, Batch: 20, Loss: 2.515802, Accuracy: 21.09%
# Epoch: 16, Batch: 21, Loss: 2.503549, Accuracy: 21.58%
# Epoch: 16, Batch: 22, Loss: 2.505547, Accuracy: 21.53%
# Epoch: 16, Batch: 23, Loss: 2.526564, Accuracy: 21.04%
# Epoch: 16, Batch: 24, Loss: 2.516296, Accuracy: 21.88%
# Epoch: 16, Batch: 25, Loss: 2.529157, Accuracy: 19.87%
# Epoch: 16, Batch: 26, Loss: 2.503651, Accuracy: 21.68%
# Epoch: 16, Batch: 27, Loss: 2.274814, Accuracy: 11.28%
# Epoch: 16, Loss: 2.603285
# Epoch: 17, Batch: 0, Loss: 2.497777, Accuracy: 21.19%
# Epoch: 17, Batch: 1, Loss: 2.512703, Accuracy: 21.29%
# Epoch: 17, Batch: 2, Loss: 2.513165, Accuracy: 22.12%
# Epoch: 17, Batch: 3, Loss: 2.502722, Accuracy: 22.46%
# Epoch: 17, Batch: 4, Loss: 2.502599, Accuracy: 21.09%
# Epoch: 17, Batch: 5, Loss: 2.489940, Accuracy: 21.34%
# Epoch: 17, Batch: 6, Loss: 2.511332, Accuracy: 21.19%
# Epoch: 17, Batch: 7, Loss: 2.501095, Accuracy: 22.12%
# Epoch: 17, Batch: 8, Loss: 2.509526, Accuracy: 21.88%
# Epoch: 17, Batch: 9, Loss: 2.511371, Accuracy: 21.73%
# Epoch: 17, Batch: 10, Loss: 2.509830, Accuracy: 21.00%
# Epoch: 17, Batch: 11, Loss: 2.516522, Accuracy: 21.29%
# Epoch: 17, Batch: 12, Loss: 2.516099, Accuracy: 21.29%
# Epoch: 17, Batch: 13, Loss: 2.506145, Accuracy: 20.95%
# Epoch: 17, Batch: 14, Loss: 2.494926, Accuracy: 22.27%
# Epoch: 17, Batch: 15, Loss: 2.515748, Accuracy: 20.85%
# Epoch: 17, Batch: 16, Loss: 2.494976, Accuracy: 22.61%
# Epoch: 17, Batch: 17, Loss: 2.505813, Accuracy: 21.97%
# Epoch: 17, Batch: 18, Loss: 2.516548, Accuracy: 20.65%
# Epoch: 17, Batch: 19, Loss: 2.500765, Accuracy: 21.39%
# Epoch: 17, Batch: 20, Loss: 2.502956, Accuracy: 21.63%
# Epoch: 17, Batch: 21, Loss: 2.487983, Accuracy: 22.36%
# Epoch: 17, Batch: 22, Loss: 2.492077, Accuracy: 21.73%
# Epoch: 17, Batch: 23, Loss: 2.512615, Accuracy: 21.63%
# Epoch: 17, Batch: 24, Loss: 2.501786, Accuracy: 22.31%
# Epoch: 17, Batch: 25, Loss: 2.515578, Accuracy: 20.46%
# Epoch: 17, Batch: 26, Loss: 2.489038, Accuracy: 21.92%
# Epoch: 17, Batch: 27, Loss: 2.247666, Accuracy: 11.72%
# Epoch: 17, Loss: 2.588122
# Epoch: 18, Batch: 0, Loss: 2.483168, Accuracy: 21.29%
# Epoch: 18, Batch: 1, Loss: 2.497349, Accuracy: 21.48%
# Epoch: 18, Batch: 2, Loss: 2.500429, Accuracy: 23.19%
# Epoch: 18, Batch: 3, Loss: 2.489098, Accuracy: 22.66%
# Epoch: 18, Batch: 4, Loss: 2.487793, Accuracy: 21.88%
# Epoch: 18, Batch: 5, Loss: 2.476067, Accuracy: 22.07%
# Epoch: 18, Batch: 6, Loss: 2.496849, Accuracy: 21.92%
# Epoch: 18, Batch: 7, Loss: 2.486595, Accuracy: 22.46%
# Epoch: 18, Batch: 8, Loss: 2.495622, Accuracy: 22.51%
# Epoch: 18, Batch: 9, Loss: 2.497462, Accuracy: 21.73%
# Epoch: 18, Batch: 10, Loss: 2.494572, Accuracy: 21.68%
# Epoch: 18, Batch: 11, Loss: 2.503240, Accuracy: 21.29%
# Epoch: 18, Batch: 12, Loss: 2.503774, Accuracy: 21.34%
# Epoch: 18, Batch: 13, Loss: 2.492627, Accuracy: 21.39%
# Epoch: 18, Batch: 14, Loss: 2.482174, Accuracy: 22.71%
# Epoch: 18, Batch: 15, Loss: 2.502495, Accuracy: 21.00%
# Epoch: 18, Batch: 16, Loss: 2.480848, Accuracy: 23.05%
# Epoch: 18, Batch: 17, Loss: 2.489884, Accuracy: 22.12%
# Epoch: 18, Batch: 18, Loss: 2.504164, Accuracy: 20.90%
# Epoch: 18, Batch: 19, Loss: 2.485945, Accuracy: 21.78%
# Epoch: 18, Batch: 20, Loss: 2.490494, Accuracy: 21.44%
# Epoch: 18, Batch: 21, Loss: 2.472727, Accuracy: 22.46%
# Epoch: 18, Batch: 22, Loss: 2.478864, Accuracy: 22.31%
# Epoch: 18, Batch: 23, Loss: 2.498620, Accuracy: 22.12%
# Epoch: 18, Batch: 24, Loss: 2.487604, Accuracy: 21.88%
# Epoch: 18, Batch: 25, Loss: 2.501653, Accuracy: 21.09%
# Epoch: 18, Batch: 26, Loss: 2.474862, Accuracy: 22.41%
# Epoch: 18, Batch: 27, Loss: 2.220597, Accuracy: 11.91%
# Epoch: 18, Loss: 2.573169
# Epoch: 19, Batch: 0, Loss: 2.468767, Accuracy: 21.83%
# Epoch: 19, Batch: 1, Loss: 2.482106, Accuracy: 21.92%
# Epoch: 19, Batch: 2, Loss: 2.488105, Accuracy: 23.19%
# Epoch: 19, Batch: 3, Loss: 2.475757, Accuracy: 22.56%
# Epoch: 19, Batch: 4, Loss: 2.473361, Accuracy: 22.17%
# Epoch: 19, Batch: 5, Loss: 2.462542, Accuracy: 22.46%
# Epoch: 19, Batch: 6, Loss: 2.482804, Accuracy: 22.27%
# Epoch: 19, Batch: 7, Loss: 2.472468, Accuracy: 22.66%
# Epoch: 19, Batch: 8, Loss: 2.481712, Accuracy: 22.90%
# Epoch: 19, Batch: 9, Loss: 2.483470, Accuracy: 22.31%
# Epoch: 19, Batch: 10, Loss: 2.479578, Accuracy: 22.80%
# Epoch: 19, Batch: 11, Loss: 2.489339, Accuracy: 21.78%
# Epoch: 19, Batch: 12, Loss: 2.491576, Accuracy: 21.68%
# Epoch: 19, Batch: 13, Loss: 2.479591, Accuracy: 21.63%
# Epoch: 19, Batch: 14, Loss: 2.469526, Accuracy: 23.10%
# Epoch: 19, Batch: 15, Loss: 2.488853, Accuracy: 21.53%
# Epoch: 19, Batch: 16, Loss: 2.466861, Accuracy: 23.05%
# Epoch: 19, Batch: 17, Loss: 2.474238, Accuracy: 22.36%
# Epoch: 19, Batch: 18, Loss: 2.491863, Accuracy: 21.29%
# Epoch: 19, Batch: 19, Loss: 2.471398, Accuracy: 22.41%
# Epoch: 19, Batch: 20, Loss: 2.478164, Accuracy: 21.63%
# Epoch: 19, Batch: 21, Loss: 2.457784, Accuracy: 23.34%
# Epoch: 19, Batch: 22, Loss: 2.465733, Accuracy: 22.66%
# Epoch: 19, Batch: 23, Loss: 2.484531, Accuracy: 22.46%
# Epoch: 19, Batch: 24, Loss: 2.473548, Accuracy: 22.36%
# Epoch: 19, Batch: 25, Loss: 2.487348, Accuracy: 21.68%
# Epoch: 19, Batch: 26, Loss: 2.461040, Accuracy: 22.41%
# Epoch: 19, Batch: 27, Loss: 2.193482, Accuracy: 11.96%
# Epoch: 19, Loss: 2.558354
# Epoch: 20, Batch: 0, Loss: 2.454618, Accuracy: 22.51%
# Epoch: 20, Batch: 1, Loss: 2.467225, Accuracy: 22.02%
# Epoch: 20, Batch: 2, Loss: 2.475931, Accuracy: 23.63%
# Epoch: 20, Batch: 3, Loss: 2.462521, Accuracy: 22.71%
# Epoch: 20, Batch: 4, Loss: 2.459136, Accuracy: 22.71%
# Epoch: 20, Batch: 5, Loss: 2.449250, Accuracy: 22.90%
# Epoch: 20, Batch: 6, Loss: 2.469151, Accuracy: 22.41%
# Epoch: 20, Batch: 7, Loss: 2.458938, Accuracy: 22.90%
# Epoch: 20, Batch: 8, Loss: 2.467722, Accuracy: 23.00%
# Epoch: 20, Batch: 9, Loss: 2.469374, Accuracy: 22.41%
# Epoch: 20, Batch: 10, Loss: 2.464792, Accuracy: 23.44%
# Epoch: 20, Batch: 11, Loss: 2.474890, Accuracy: 22.27%
# Epoch: 20, Batch: 12, Loss: 2.479225, Accuracy: 22.31%
# Epoch: 20, Batch: 13, Loss: 2.467001, Accuracy: 22.31%
# Epoch: 20, Batch: 14, Loss: 2.456857, Accuracy: 23.54%
# Epoch: 20, Batch: 15, Loss: 2.474634, Accuracy: 21.78%
# Epoch: 20, Batch: 16, Loss: 2.452964, Accuracy: 23.88%
# Epoch: 20, Batch: 17, Loss: 2.459026, Accuracy: 22.75%
# Epoch: 20, Batch: 18, Loss: 2.479529, Accuracy: 22.02%
# Epoch: 20, Batch: 19, Loss: 2.456991, Accuracy: 22.95%
# Epoch: 20, Batch: 20, Loss: 2.465792, Accuracy: 21.73%
# Epoch: 20, Batch: 21, Loss: 2.442908, Accuracy: 23.97%
# Epoch: 20, Batch: 22, Loss: 2.452673, Accuracy: 23.19%
# Epoch: 20, Batch: 23, Loss: 2.470442, Accuracy: 22.71%
# Epoch: 20, Batch: 24, Loss: 2.459515, Accuracy: 22.85%
# Epoch: 20, Batch: 25, Loss: 2.472881, Accuracy: 21.88%
# Epoch: 20, Batch: 26, Loss: 2.447469, Accuracy: 22.90%
# Epoch: 20, Batch: 27, Loss: 2.166234, Accuracy: 12.11%
# Epoch:  20  Validation Loss:  159.91999999999953
# Epoch: 20, Loss: 2.543618
# Epoch: 21, Batch: 0, Loss: 2.440886, Accuracy: 23.34%
# Epoch: 21, Batch: 1, Loss: 2.452610, Accuracy: 22.66%
# Epoch: 21, Batch: 2, Loss: 2.463569, Accuracy: 24.02%
# Epoch: 21, Batch: 3, Loss: 2.449184, Accuracy: 22.80%
# Epoch: 21, Batch: 4, Loss: 2.445102, Accuracy: 23.34%
# Epoch: 21, Batch: 5, Loss: 2.436004, Accuracy: 23.58%
# Epoch: 21, Batch: 6, Loss: 2.455829, Accuracy: 23.14%
# Epoch: 21, Batch: 7, Loss: 2.446140, Accuracy: 23.24%
# Epoch: 21, Batch: 8, Loss: 2.453809, Accuracy: 23.39%
# Epoch: 21, Batch: 9, Loss: 2.455417, Accuracy: 22.56%
# Epoch: 21, Batch: 10, Loss: 2.450020, Accuracy: 23.68%
# Epoch: 21, Batch: 11, Loss: 2.460122, Accuracy: 23.10%
# Epoch: 21, Batch: 12, Loss: 2.466570, Accuracy: 22.36%
# Epoch: 21, Batch: 13, Loss: 2.454919, Accuracy: 22.90%
# Epoch: 21, Batch: 14, Loss: 2.443867, Accuracy: 23.78%
# Epoch: 21, Batch: 15, Loss: 2.459768, Accuracy: 21.88%
# Epoch: 21, Batch: 16, Loss: 2.439126, Accuracy: 24.37%
# Epoch: 21, Batch: 17, Loss: 2.444253, Accuracy: 23.29%
# Epoch: 21, Batch: 18, Loss: 2.467154, Accuracy: 22.41%
# Epoch: 21, Batch: 19, Loss: 2.442677, Accuracy: 23.24%
# Epoch: 21, Batch: 20, Loss: 2.453316, Accuracy: 22.12%
# Epoch: 21, Batch: 21, Loss: 2.427881, Accuracy: 24.27%
# Epoch: 21, Batch: 22, Loss: 2.439737, Accuracy: 23.63%
# Epoch: 21, Batch: 23, Loss: 2.456539, Accuracy: 22.85%
# Epoch: 21, Batch: 24, Loss: 2.445527, Accuracy: 23.10%
# Epoch: 21, Batch: 25, Loss: 2.458622, Accuracy: 21.97%
# Epoch: 21, Batch: 26, Loss: 2.434089, Accuracy: 23.39%
# Epoch: 21, Batch: 27, Loss: 2.138883, Accuracy: 12.26%
# Epoch: 21, Loss: 2.528949
# Epoch: 22, Batch: 0, Loss: 2.427653, Accuracy: 23.73%
# Epoch: 22, Batch: 1, Loss: 2.438155, Accuracy: 23.44%
# Epoch: 22, Batch: 2, Loss: 2.450744, Accuracy: 24.41%
# Epoch: 22, Batch: 3, Loss: 2.435709, Accuracy: 23.14%
# Epoch: 22, Batch: 4, Loss: 2.431348, Accuracy: 23.63%
# Epoch: 22, Batch: 5, Loss: 2.422705, Accuracy: 23.78%
# Epoch: 22, Batch: 6, Loss: 2.442727, Accuracy: 23.44%
# Epoch: 22, Batch: 7, Loss: 2.433951, Accuracy: 23.68%
# Epoch: 22, Batch: 8, Loss: 2.440139, Accuracy: 23.58%
# Epoch: 22, Batch: 9, Loss: 2.441921, Accuracy: 22.80%
# Epoch: 22, Batch: 10, Loss: 2.435220, Accuracy: 24.12%
# Epoch: 22, Batch: 11, Loss: 2.445307, Accuracy: 23.97%
# Epoch: 22, Batch: 12, Loss: 2.453519, Accuracy: 22.56%
# Epoch: 22, Batch: 13, Loss: 2.443199, Accuracy: 23.44%
# Epoch: 22, Batch: 14, Loss: 2.430229, Accuracy: 24.02%
# Epoch: 22, Batch: 15, Loss: 2.444419, Accuracy: 22.17%
# Epoch: 22, Batch: 16, Loss: 2.425363, Accuracy: 24.37%
# Epoch: 22, Batch: 17, Loss: 2.429695, Accuracy: 23.44%
# Epoch: 22, Batch: 18, Loss: 2.454771, Accuracy: 22.90%
# Epoch: 22, Batch: 19, Loss: 2.428610, Accuracy: 23.93%
# Epoch: 22, Batch: 20, Loss: 2.440791, Accuracy: 22.41%
# Epoch: 22, Batch: 21, Loss: 2.412731, Accuracy: 24.37%
# Epoch: 22, Batch: 22, Loss: 2.426898, Accuracy: 24.32%
# Epoch: 22, Batch: 23, Loss: 2.442962, Accuracy: 22.95%
# Epoch: 22, Batch: 24, Loss: 2.431682, Accuracy: 23.83%
# Epoch: 22, Batch: 25, Loss: 2.444749, Accuracy: 22.27%
# Epoch: 22, Batch: 26, Loss: 2.420861, Accuracy: 23.58%
# Epoch: 22, Batch: 27, Loss: 2.111635, Accuracy: 12.89%
# Epoch: 22, Loss: 2.514359
# Epoch: 23, Batch: 0, Loss: 2.414766, Accuracy: 24.56%
# Epoch: 23, Batch: 1, Loss: 2.423831, Accuracy: 23.97%
# Epoch: 23, Batch: 2, Loss: 2.437303, Accuracy: 24.41%
# Epoch: 23, Batch: 3, Loss: 2.422168, Accuracy: 23.88%
# Epoch: 23, Batch: 4, Loss: 2.417861, Accuracy: 24.02%
# Epoch: 23, Batch: 5, Loss: 2.409433, Accuracy: 23.88%
# Epoch: 23, Batch: 6, Loss: 2.429746, Accuracy: 23.68%
# Epoch: 23, Batch: 7, Loss: 2.422086, Accuracy: 23.97%
# Epoch: 23, Batch: 8, Loss: 2.426822, Accuracy: 24.12%
# Epoch: 23, Batch: 9, Loss: 2.429072, Accuracy: 23.10%
# Epoch: 23, Batch: 10, Loss: 2.420494, Accuracy: 24.12%
# Epoch: 23, Batch: 11, Loss: 2.430694, Accuracy: 24.32%
# Epoch: 23, Batch: 12, Loss: 2.440170, Accuracy: 22.02%
# Epoch: 23, Batch: 13, Loss: 2.431428, Accuracy: 24.07%
# Epoch: 23, Batch: 14, Loss: 2.415910, Accuracy: 24.61%
# Epoch: 23, Batch: 15, Loss: 2.428778, Accuracy: 22.51%
# Epoch: 23, Batch: 16, Loss: 2.411722, Accuracy: 24.76%
# Epoch: 23, Batch: 17, Loss: 2.415084, Accuracy: 23.78%
# Epoch: 23, Batch: 18, Loss: 2.442287, Accuracy: 23.14%
# Epoch: 23, Batch: 19, Loss: 2.415033, Accuracy: 23.93%
# Epoch: 23, Batch: 20, Loss: 2.428257, Accuracy: 23.00%
# Epoch: 23, Batch: 21, Loss: 2.397606, Accuracy: 24.22%
# Epoch: 23, Batch: 22, Loss: 2.414073, Accuracy: 24.41%
# Epoch: 23, Batch: 23, Loss: 2.429693, Accuracy: 23.05%
# Epoch: 23, Batch: 24, Loss: 2.418107, Accuracy: 23.93%
# Epoch: 23, Batch: 25, Loss: 2.431338, Accuracy: 22.90%
# Epoch: 23, Batch: 26, Loss: 2.407716, Accuracy: 24.07%
# Epoch: 23, Batch: 27, Loss: 2.084731, Accuracy: 13.53%
# Epoch: 23, Loss: 2.499860
# Epoch: 24, Batch: 0, Loss: 2.402108, Accuracy: 24.22%
# Epoch: 24, Batch: 1, Loss: 2.409626, Accuracy: 24.17%
# Epoch: 24, Batch: 2, Loss: 2.423269, Accuracy: 24.76%
# Epoch: 24, Batch: 3, Loss: 2.408652, Accuracy: 24.17%
# Epoch: 24, Batch: 4, Loss: 2.404613, Accuracy: 24.32%
# Epoch: 24, Batch: 5, Loss: 2.396329, Accuracy: 23.97%
# Epoch: 24, Batch: 6, Loss: 2.416887, Accuracy: 23.73%
# Epoch: 24, Batch: 7, Loss: 2.410309, Accuracy: 24.66%
# Epoch: 24, Batch: 8, Loss: 2.413840, Accuracy: 24.61%
# Epoch: 24, Batch: 9, Loss: 2.416914, Accuracy: 22.75%
# Epoch: 24, Batch: 10, Loss: 2.406081, Accuracy: 23.88%
# Epoch: 24, Batch: 11, Loss: 2.416387, Accuracy: 24.56%
# Epoch: 24, Batch: 12, Loss: 2.426682, Accuracy: 23.00%
# Epoch: 24, Batch: 13, Loss: 2.419222, Accuracy: 23.83%
# Epoch: 24, Batch: 14, Loss: 2.401177, Accuracy: 25.05%
# Epoch: 24, Batch: 15, Loss: 2.413071, Accuracy: 23.05%
# Epoch: 24, Batch: 16, Loss: 2.398255, Accuracy: 25.24%
# Epoch: 24, Batch: 17, Loss: 2.400318, Accuracy: 24.22%
# Epoch: 24, Batch: 18, Loss: 2.429561, Accuracy: 23.05%
# Epoch: 24, Batch: 19, Loss: 2.402098, Accuracy: 24.22%
# Epoch: 24, Batch: 20, Loss: 2.415610, Accuracy: 23.34%
# Epoch: 24, Batch: 21, Loss: 2.382662, Accuracy: 24.76%
# Epoch: 24, Batch: 22, Loss: 2.401264, Accuracy: 24.90%
# Epoch: 24, Batch: 23, Loss: 2.416764, Accuracy: 23.14%
# Epoch: 24, Batch: 24, Loss: 2.404946, Accuracy: 24.51%
# Epoch: 24, Batch: 25, Loss: 2.418440, Accuracy: 23.44%
# Epoch: 24, Batch: 26, Loss: 2.394645, Accuracy: 24.02%
# Epoch: 24, Batch: 27, Loss: 2.058491, Accuracy: 13.57%
# Epoch: 24, Loss: 2.485490
# Epoch: 25, Batch: 0, Loss: 2.389821, Accuracy: 24.27%
# Epoch: 25, Batch: 1, Loss: 2.395587, Accuracy: 24.07%
# Epoch: 25, Batch: 2, Loss: 2.408881, Accuracy: 25.10%
# Epoch: 25, Batch: 3, Loss: 2.395285, Accuracy: 24.71%
# Epoch: 25, Batch: 4, Loss: 2.391693, Accuracy: 24.76%
# Epoch: 25, Batch: 5, Loss: 2.383511, Accuracy: 24.41%
# Epoch: 25, Batch: 6, Loss: 2.404260, Accuracy: 23.83%
# Epoch: 25, Batch: 7, Loss: 2.398525, Accuracy: 24.71%
# Epoch: 25, Batch: 8, Loss: 2.401179, Accuracy: 24.66%
# Epoch: 25, Batch: 9, Loss: 2.405398, Accuracy: 22.61%
# Epoch: 25, Batch: 10, Loss: 2.392211, Accuracy: 24.61%
# Epoch: 25, Batch: 11, Loss: 2.402341, Accuracy: 24.90%
# Epoch: 25, Batch: 12, Loss: 2.413167, Accuracy: 23.29%
# Epoch: 25, Batch: 13, Loss: 2.406478, Accuracy: 24.22%
# Epoch: 25, Batch: 14, Loss: 2.386358, Accuracy: 25.49%
# Epoch: 25, Batch: 15, Loss: 2.397552, Accuracy: 23.73%
# Epoch: 25, Batch: 16, Loss: 2.385045, Accuracy: 25.44%
# Epoch: 25, Batch: 17, Loss: 2.385658, Accuracy: 24.76%
# Epoch: 25, Batch: 18, Loss: 2.416622, Accuracy: 23.49%
# Epoch: 25, Batch: 19, Loss: 2.389734, Accuracy: 24.71%
# Epoch: 25, Batch: 20, Loss: 2.402770, Accuracy: 23.14%
# Epoch: 25, Batch: 21, Loss: 2.368083, Accuracy: 25.24%
# Epoch: 25, Batch: 22, Loss: 2.388619, Accuracy: 24.90%
# Epoch: 25, Batch: 23, Loss: 2.404270, Accuracy: 23.68%
# Epoch: 25, Batch: 24, Loss: 2.392197, Accuracy: 24.51%
# Epoch: 25, Batch: 25, Loss: 2.406006, Accuracy: 23.54%
# Epoch: 25, Batch: 26, Loss: 2.381744, Accuracy: 23.78%
# Epoch: 25, Batch: 27, Loss: 2.033225, Accuracy: 14.06%
# Epoch: 25, Loss: 2.471341
# Epoch: 26, Batch: 0, Loss: 2.378091, Accuracy: 24.66%
# Epoch: 26, Batch: 1, Loss: 2.381743, Accuracy: 24.17%
# Epoch: 26, Batch: 2, Loss: 2.394330, Accuracy: 25.73%
# Epoch: 26, Batch: 3, Loss: 2.382099, Accuracy: 25.34%
# Epoch: 26, Batch: 4, Loss: 2.379035, Accuracy: 25.15%
# Epoch: 26, Batch: 5, Loss: 2.371065, Accuracy: 24.76%
# Epoch: 26, Batch: 6, Loss: 2.391850, Accuracy: 24.71%
# Epoch: 26, Batch: 7, Loss: 2.386675, Accuracy: 24.85%
# Epoch: 26, Batch: 8, Loss: 2.388823, Accuracy: 24.80%
# Epoch: 26, Batch: 9, Loss: 2.394351, Accuracy: 22.75%
# Epoch: 26, Batch: 10, Loss: 2.378930, Accuracy: 24.51%
# Epoch: 26, Batch: 11, Loss: 2.388562, Accuracy: 25.15%
# Epoch: 26, Batch: 12, Loss: 2.399604, Accuracy: 23.97%
# Epoch: 26, Batch: 13, Loss: 2.393196, Accuracy: 24.76%
# Epoch: 26, Batch: 14, Loss: 2.371763, Accuracy: 25.93%
# Epoch: 26, Batch: 15, Loss: 2.382276, Accuracy: 24.37%
# Epoch: 26, Batch: 16, Loss: 2.372198, Accuracy: 25.78%
# Epoch: 26, Batch: 17, Loss: 2.371596, Accuracy: 24.90%
# Epoch: 26, Batch: 18, Loss: 2.403708, Accuracy: 23.68%
# Epoch: 26, Batch: 19, Loss: 2.377727, Accuracy: 25.44%
# Epoch: 26, Batch: 20, Loss: 2.389815, Accuracy: 24.12%
# Epoch: 26, Batch: 21, Loss: 2.354020, Accuracy: 25.29%
# Epoch: 26, Batch: 22, Loss: 2.376364, Accuracy: 24.46%
# Epoch: 26, Batch: 23, Loss: 2.392273, Accuracy: 24.37%
# Epoch: 26, Batch: 24, Loss: 2.379795, Accuracy: 24.76%
# Epoch: 26, Batch: 25, Loss: 2.394094, Accuracy: 24.17%
# Epoch: 26, Batch: 26, Loss: 2.369170, Accuracy: 23.73%
# Epoch: 26, Batch: 27, Loss: 2.008993, Accuracy: 14.36%
# Epoch: 26, Loss: 2.457487
# Epoch: 27, Batch: 0, Loss: 2.366885, Accuracy: 25.34%
# Epoch: 27, Batch: 1, Loss: 2.368235, Accuracy: 24.61%
# Epoch: 27, Batch: 2, Loss: 2.379764, Accuracy: 25.93%
# Epoch: 27, Batch: 3, Loss: 2.369037, Accuracy: 25.49%
# Epoch: 27, Batch: 4, Loss: 2.366641, Accuracy: 25.59%
# Epoch: 27, Batch: 5, Loss: 2.359015, Accuracy: 25.29%
# Epoch: 27, Batch: 6, Loss: 2.379415, Accuracy: 24.76%
# Epoch: 27, Batch: 7, Loss: 2.374738, Accuracy: 24.90%
# Epoch: 27, Batch: 8, Loss: 2.376712, Accuracy: 25.24%
# Epoch: 27, Batch: 9, Loss: 2.383497, Accuracy: 22.95%
# Epoch: 27, Batch: 10, Loss: 2.366323, Accuracy: 24.90%
# Epoch: 27, Batch: 11, Loss: 2.375069, Accuracy: 25.93%
# Epoch: 27, Batch: 12, Loss: 2.385959, Accuracy: 24.17%
# Epoch: 27, Batch: 13, Loss: 2.379560, Accuracy: 25.05%
# Epoch: 27, Batch: 14, Loss: 2.357625, Accuracy: 26.56%
# Epoch: 27, Batch: 15, Loss: 2.367252, Accuracy: 24.95%
# Epoch: 27, Batch: 16, Loss: 2.359784, Accuracy: 25.98%
# Epoch: 27, Batch: 17, Loss: 2.358581, Accuracy: 25.24%
# Epoch: 27, Batch: 18, Loss: 2.391053, Accuracy: 24.22%
# Epoch: 27, Batch: 19, Loss: 2.365976, Accuracy: 25.88%
# Epoch: 27, Batch: 20, Loss: 2.376794, Accuracy: 24.46%
# Epoch: 27, Batch: 21, Loss: 2.340451, Accuracy: 26.12%
# Epoch: 27, Batch: 22, Loss: 2.364522, Accuracy: 24.51%
# Epoch: 27, Batch: 23, Loss: 2.380863, Accuracy: 25.29%
# Epoch: 27, Batch: 24, Loss: 2.367896, Accuracy: 24.71%
# Epoch: 27, Batch: 25, Loss: 2.382642, Accuracy: 24.51%
# Epoch: 27, Batch: 26, Loss: 2.357022, Accuracy: 23.97%
# Epoch: 27, Batch: 27, Loss: 1.985666, Accuracy: 14.31%
# Epoch: 27, Loss: 2.443962
# Epoch: 28, Batch: 0, Loss: 2.355952, Accuracy: 25.34%
# Epoch: 28, Batch: 1, Loss: 2.355149, Accuracy: 25.00%
# Epoch: 28, Batch: 2, Loss: 2.365251, Accuracy: 26.03%
# Epoch: 28, Batch: 3, Loss: 2.356123, Accuracy: 25.10%
# Epoch: 28, Batch: 4, Loss: 2.354708, Accuracy: 25.98%
# Epoch: 28, Batch: 5, Loss: 2.347301, Accuracy: 25.29%
# Epoch: 28, Batch: 6, Loss: 2.366708, Accuracy: 24.66%
# Epoch: 28, Batch: 7, Loss: 2.362817, Accuracy: 25.49%
# Epoch: 28, Batch: 8, Loss: 2.364807, Accuracy: 25.49%
# Epoch: 28, Batch: 9, Loss: 2.372522, Accuracy: 23.14%
# Epoch: 28, Batch: 10, Loss: 2.354579, Accuracy: 25.15%
# Epoch: 28, Batch: 11, Loss: 2.361830, Accuracy: 26.22%
# Epoch: 28, Batch: 12, Loss: 2.372532, Accuracy: 24.80%
# Epoch: 28, Batch: 13, Loss: 2.365932, Accuracy: 25.34%
# Epoch: 28, Batch: 14, Loss: 2.344070, Accuracy: 26.76%
# Epoch: 28, Batch: 15, Loss: 2.352577, Accuracy: 25.15%
# Epoch: 28, Batch: 16, Loss: 2.347822, Accuracy: 26.12%
# Epoch: 28, Batch: 17, Loss: 2.346578, Accuracy: 25.24%
# Epoch: 28, Batch: 18, Loss: 2.378570, Accuracy: 24.71%
# Epoch: 28, Batch: 19, Loss: 2.354458, Accuracy: 26.27%
# Epoch: 28, Batch: 20, Loss: 2.363685, Accuracy: 25.00%
# Epoch: 28, Batch: 21, Loss: 2.327345, Accuracy: 26.32%
# Epoch: 28, Batch: 22, Loss: 2.352821, Accuracy: 24.95%
# Epoch: 28, Batch: 23, Loss: 2.370044, Accuracy: 25.44%
# Epoch: 28, Batch: 24, Loss: 2.356569, Accuracy: 24.85%
# Epoch: 28, Batch: 25, Loss: 2.371357, Accuracy: 24.80%
# Epoch: 28, Batch: 26, Loss: 2.345210, Accuracy: 24.46%
# Epoch: 28, Batch: 27, Loss: 1.963216, Accuracy: 14.40%
# Epoch: 28, Loss: 2.430760
# Epoch: 29, Batch: 0, Loss: 2.344980, Accuracy: 25.44%
# Epoch: 29, Batch: 1, Loss: 2.342303, Accuracy: 25.34%
# Epoch: 29, Batch: 2, Loss: 2.350844, Accuracy: 26.12%
# Epoch: 29, Batch: 3, Loss: 2.343377, Accuracy: 24.95%
# Epoch: 29, Batch: 4, Loss: 2.343272, Accuracy: 26.07%
# Epoch: 29, Batch: 5, Loss: 2.335880, Accuracy: 25.44%
# Epoch: 29, Batch: 6, Loss: 2.353658, Accuracy: 25.00%
# Epoch: 29, Batch: 7, Loss: 2.351084, Accuracy: 25.83%
# Epoch: 29, Batch: 8, Loss: 2.353057, Accuracy: 25.29%
# Epoch: 29, Batch: 9, Loss: 2.361165, Accuracy: 23.19%
# Epoch: 29, Batch: 10, Loss: 2.343678, Accuracy: 25.59%
# Epoch: 29, Batch: 11, Loss: 2.348904, Accuracy: 26.81%
# Epoch: 29, Batch: 12, Loss: 2.359857, Accuracy: 25.24%
# Epoch: 29, Batch: 13, Loss: 2.352639, Accuracy: 25.15%
# Epoch: 29, Batch: 14, Loss: 2.331177, Accuracy: 26.81%
# Epoch: 29, Batch: 15, Loss: 2.338326, Accuracy: 25.34%
# Epoch: 29, Batch: 16, Loss: 2.336128, Accuracy: 26.17%
# Epoch: 29, Batch: 17, Loss: 2.335166, Accuracy: 25.93%
# Epoch: 29, Batch: 18, Loss: 2.365887, Accuracy: 24.90%
# Epoch: 29, Batch: 19, Loss: 2.343063, Accuracy: 26.51%
# Epoch: 29, Batch: 20, Loss: 2.350564, Accuracy: 25.54%
# Epoch: 29, Batch: 21, Loss: 2.314814, Accuracy: 26.71%
# Epoch: 29, Batch: 22, Loss: 2.340993, Accuracy: 25.29%
# Epoch: 29, Batch: 23, Loss: 2.359664, Accuracy: 25.49%
# Epoch: 29, Batch: 24, Loss: 2.345787, Accuracy: 25.20%
# Epoch: 29, Batch: 25, Loss: 2.360039, Accuracy: 25.00%
# Epoch: 29, Batch: 26, Loss: 2.333652, Accuracy: 25.00%
# Epoch: 29, Batch: 27, Loss: 1.941870, Accuracy: 14.60%
# Epoch: 29, Loss: 2.417845
# Epoch: 30, Batch: 0, Loss: 2.333814, Accuracy: 25.59%
# Epoch: 30, Batch: 1, Loss: 2.329403, Accuracy: 25.34%
# Epoch: 30, Batch: 2, Loss: 2.336894, Accuracy: 26.51%
# Epoch: 30, Batch: 3, Loss: 2.330562, Accuracy: 25.10%
# Epoch: 30, Batch: 4, Loss: 2.332102, Accuracy: 25.88%
# Epoch: 30, Batch: 5, Loss: 2.324797, Accuracy: 25.73%
# Epoch: 30, Batch: 6, Loss: 2.340559, Accuracy: 25.29%
# Epoch: 30, Batch: 7, Loss: 2.339576, Accuracy: 26.12%
# Epoch: 30, Batch: 8, Loss: 2.341488, Accuracy: 25.83%
# Epoch: 30, Batch: 9, Loss: 2.349347, Accuracy: 23.14%
# Epoch: 30, Batch: 10, Loss: 2.333345, Accuracy: 25.83%
# Epoch: 30, Batch: 11, Loss: 2.336411, Accuracy: 27.20%
# Epoch: 30, Batch: 12, Loss: 2.348248, Accuracy: 25.05%
# Epoch: 30, Batch: 13, Loss: 2.339976, Accuracy: 24.95%
# Epoch: 30, Batch: 14, Loss: 2.318957, Accuracy: 27.29%
# Epoch: 30, Batch: 15, Loss: 2.324617, Accuracy: 25.83%
# Epoch: 30, Batch: 16, Loss: 2.324476, Accuracy: 26.81%
# Epoch: 30, Batch: 17, Loss: 2.323877, Accuracy: 25.93%
# Epoch: 30, Batch: 18, Loss: 2.352800, Accuracy: 24.80%
# Epoch: 30, Batch: 19, Loss: 2.331632, Accuracy: 26.46%
# Epoch: 30, Batch: 20, Loss: 2.337590, Accuracy: 25.29%
# Epoch: 30, Batch: 21, Loss: 2.303113, Accuracy: 26.76%
# Epoch: 30, Batch: 22, Loss: 2.329014, Accuracy: 25.73%
# Epoch: 30, Batch: 23, Loss: 2.349423, Accuracy: 25.63%
# Epoch: 30, Batch: 24, Loss: 2.335311, Accuracy: 25.73%
# Epoch: 30, Batch: 25, Loss: 2.348663, Accuracy: 25.29%
# Epoch: 30, Batch: 26, Loss: 2.322295, Accuracy: 25.20%
# ...
# Epoch: 989, Batch: 27, Loss: 0.143109, Accuracy: 32.67%
# Epoch: 989, Loss: 0.365340
# Epoch: 990, Batch: 0, Loss: 0.354983, Accuracy: 85.06%
# Epoch: 990, Batch: 1, Loss: 0.338741, Accuracy: 84.91%
# Epoch: 990, Batch: 2, Loss: 0.348772, Accuracy: 84.13%
# Epoch: 990, Batch: 3, Loss: 0.340665, Accuracy: 84.42%
# Epoch: 990, Batch: 4, Loss: 0.334333, Accuracy: 85.25%
# Epoch: 990, Batch: 5, Loss: 0.332022, Accuracy: 84.77%
# Epoch: 990, Batch: 6, Loss: 0.365596, Accuracy: 83.64%
# Epoch: 990, Batch: 7, Loss: 0.344764, Accuracy: 85.16%
# Epoch: 990, Batch: 8, Loss: 0.335430, Accuracy: 85.30%
# Epoch: 990, Batch: 9, Loss: 0.356938, Accuracy: 84.13%
# Epoch: 990, Batch: 10, Loss: 0.334058, Accuracy: 84.67%
# Epoch: 990, Batch: 11, Loss: 0.342480, Accuracy: 85.55%
# Epoch: 990, Batch: 12, Loss: 0.334445, Accuracy: 84.86%
# Epoch: 990, Batch: 13, Loss: 0.329522, Accuracy: 84.86%
# Epoch: 990, Batch: 14, Loss: 0.332379, Accuracy: 84.28%
# Epoch: 990, Batch: 15, Loss: 0.316912, Accuracy: 86.28%
# Epoch: 990, Batch: 16, Loss: 0.335434, Accuracy: 84.42%
# Epoch: 990, Batch: 17, Loss: 0.334558, Accuracy: 85.50%
# Epoch: 990, Batch: 18, Loss: 0.326122, Accuracy: 86.67%
# Epoch: 990, Batch: 19, Loss: 0.325638, Accuracy: 85.64%
# Epoch: 990, Batch: 20, Loss: 0.344162, Accuracy: 84.67%
# Epoch: 990, Batch: 21, Loss: 0.325892, Accuracy: 86.33%
# Epoch: 990, Batch: 22, Loss: 0.329901, Accuracy: 85.21%
# Epoch: 990, Batch: 23, Loss: 0.316261, Accuracy: 86.87%
# Epoch: 990, Batch: 24, Loss: 0.362298, Accuracy: 84.23%
# Epoch: 990, Batch: 25, Loss: 0.323234, Accuracy: 85.60%
# Epoch: 990, Batch: 26, Loss: 0.325327, Accuracy: 86.23%
# Epoch: 990, Batch: 27, Loss: 0.130973, Accuracy: 32.76%
# Epoch:  990  Validation Loss:  159.91999999999953
# Epoch: 990, Loss: 0.341550
# Epoch: 991, Batch: 0, Loss: 0.344487, Accuracy: 85.35%
# Epoch: 991, Batch: 1, Loss: 0.333474, Accuracy: 85.35%
# Epoch: 991, Batch: 2, Loss: 0.321743, Accuracy: 85.11%
# Epoch: 991, Batch: 3, Loss: 0.330936, Accuracy: 85.69%
# Epoch: 991, Batch: 4, Loss: 0.326366, Accuracy: 85.60%
# Epoch: 991, Batch: 5, Loss: 0.313097, Accuracy: 86.28%
# Epoch: 991, Batch: 6, Loss: 0.333980, Accuracy: 85.01%
# Epoch: 991, Batch: 7, Loss: 0.329810, Accuracy: 85.79%
# Epoch: 991, Batch: 8, Loss: 0.317952, Accuracy: 86.18%
# Epoch: 991, Batch: 9, Loss: 0.328978, Accuracy: 85.45%
# Epoch: 991, Batch: 10, Loss: 0.334282, Accuracy: 84.91%
# Epoch: 991, Batch: 11, Loss: 0.330891, Accuracy: 86.43%
# Epoch: 991, Batch: 12, Loss: 0.322309, Accuracy: 86.13%
# Epoch: 991, Batch: 13, Loss: 0.315876, Accuracy: 86.04%
# Epoch: 991, Batch: 14, Loss: 0.326492, Accuracy: 85.06%
# Epoch: 991, Batch: 15, Loss: 0.293500, Accuracy: 87.74%
# Epoch: 991, Batch: 16, Loss: 0.325933, Accuracy: 85.55%
# Epoch: 991, Batch: 17, Loss: 0.327180, Accuracy: 85.74%
# Epoch: 991, Batch: 18, Loss: 0.316821, Accuracy: 86.18%
# Epoch: 991, Batch: 19, Loss: 0.311391, Accuracy: 86.52%
# Epoch: 991, Batch: 20, Loss: 0.336142, Accuracy: 84.86%
# Epoch: 991, Batch: 21, Loss: 0.308596, Accuracy: 86.82%
# Epoch: 991, Batch: 22, Loss: 0.322656, Accuracy: 85.74%
# Epoch: 991, Batch: 23, Loss: 0.301707, Accuracy: 87.60%
# Epoch: 991, Batch: 24, Loss: 0.338701, Accuracy: 85.30%
# Epoch: 991, Batch: 25, Loss: 0.307141, Accuracy: 87.21%
# Epoch: 991, Batch: 26, Loss: 0.313923, Accuracy: 86.47%
# Epoch: 991, Batch: 27, Loss: 0.125605, Accuracy: 32.81%
# Epoch: 991, Loss: 0.327406
# Epoch: 992, Batch: 0, Loss: 0.329722, Accuracy: 86.87%
# Epoch: 992, Batch: 1, Loss: 0.319711, Accuracy: 85.89%
# Epoch: 992, Batch: 2, Loss: 0.303995, Accuracy: 86.38%
# Epoch: 992, Batch: 3, Loss: 0.312110, Accuracy: 86.43%
# Epoch: 992, Batch: 4, Loss: 0.312998, Accuracy: 86.67%
# Epoch: 992, Batch: 5, Loss: 0.301247, Accuracy: 86.57%
# Epoch: 992, Batch: 6, Loss: 0.321172, Accuracy: 85.25%
# Epoch: 992, Batch: 7, Loss: 0.309982, Accuracy: 86.77%
# Epoch: 992, Batch: 8, Loss: 0.303376, Accuracy: 87.06%
# Epoch: 992, Batch: 9, Loss: 0.323974, Accuracy: 86.28%
# Epoch: 992, Batch: 10, Loss: 0.311788, Accuracy: 86.43%
# Epoch: 992, Batch: 11, Loss: 0.315223, Accuracy: 87.35%
# Epoch: 992, Batch: 12, Loss: 0.316487, Accuracy: 86.18%
# Epoch: 992, Batch: 13, Loss: 0.309671, Accuracy: 86.47%
# Epoch: 992, Batch: 14, Loss: 0.321280, Accuracy: 85.60%
# Epoch: 992, Batch: 15, Loss: 0.293824, Accuracy: 87.50%
# Epoch: 992, Batch: 16, Loss: 0.312796, Accuracy: 85.94%
# Epoch: 992, Batch: 17, Loss: 0.310590, Accuracy: 87.06%
# Epoch: 992, Batch: 18, Loss: 0.299434, Accuracy: 87.35%
# Epoch: 992, Batch: 19, Loss: 0.295477, Accuracy: 87.45%
# Epoch: 992, Batch: 20, Loss: 0.324207, Accuracy: 85.94%
# Epoch: 992, Batch: 21, Loss: 0.294586, Accuracy: 87.99%
# Epoch: 992, Batch: 22, Loss: 0.303784, Accuracy: 86.91%
# Epoch: 992, Batch: 23, Loss: 0.287271, Accuracy: 88.33%
# Epoch: 992, Batch: 24, Loss: 0.334488, Accuracy: 85.79%
# Epoch: 992, Batch: 25, Loss: 0.305379, Accuracy: 86.72%
# Epoch: 992, Batch: 26, Loss: 0.308957, Accuracy: 86.96%
# Epoch: 992, Batch: 27, Loss: 0.127105, Accuracy: 32.86%
# Epoch: 992, Loss: 0.315209
# Epoch: 993, Batch: 0, Loss: 0.323069, Accuracy: 86.57%
# Epoch: 993, Batch: 1, Loss: 0.307484, Accuracy: 87.30%
# Epoch: 993, Batch: 2, Loss: 0.296421, Accuracy: 87.45%
# Epoch: 993, Batch: 3, Loss: 0.299789, Accuracy: 87.60%
# Epoch: 993, Batch: 4, Loss: 0.304108, Accuracy: 87.40%
# Epoch: 993, Batch: 5, Loss: 0.298412, Accuracy: 86.57%
# Epoch: 993, Batch: 6, Loss: 0.311388, Accuracy: 85.79%
# Epoch: 993, Batch: 7, Loss: 0.308546, Accuracy: 86.91%
# Epoch: 993, Batch: 8, Loss: 0.289693, Accuracy: 88.04%
# Epoch: 993, Batch: 9, Loss: 0.309052, Accuracy: 87.35%
# Epoch: 993, Batch: 10, Loss: 0.308123, Accuracy: 86.38%
# Epoch: 993, Batch: 11, Loss: 0.306958, Accuracy: 87.60%
# Epoch: 993, Batch: 12, Loss: 0.302796, Accuracy: 87.21%
# Epoch: 993, Batch: 13, Loss: 0.299338, Accuracy: 87.70%
# Epoch: 993, Batch: 14, Loss: 0.309414, Accuracy: 85.94%
# Epoch: 993, Batch: 15, Loss: 0.286080, Accuracy: 88.57%
# Epoch: 993, Batch: 16, Loss: 0.298792, Accuracy: 87.21%
# Epoch: 993, Batch: 17, Loss: 0.294293, Accuracy: 87.65%
# Epoch: 993, Batch: 18, Loss: 0.291907, Accuracy: 87.79%
# Epoch: 993, Batch: 19, Loss: 0.298002, Accuracy: 87.26%
# Epoch: 993, Batch: 20, Loss: 0.313871, Accuracy: 87.06%
# Epoch: 993, Batch: 21, Loss: 0.285343, Accuracy: 88.72%
# Epoch: 993, Batch: 22, Loss: 0.296748, Accuracy: 87.30%
# Epoch: 993, Batch: 23, Loss: 0.283021, Accuracy: 88.82%
# Epoch: 993, Batch: 24, Loss: 0.321416, Accuracy: 86.33%
# Epoch: 993, Batch: 25, Loss: 0.292664, Accuracy: 87.74%
# Epoch: 993, Batch: 26, Loss: 0.301659, Accuracy: 87.01%
# Epoch: 993, Batch: 27, Loss: 0.119839, Accuracy: 32.96%
# Epoch: 993, Loss: 0.305860
# Epoch: 994, Batch: 0, Loss: 0.310240, Accuracy: 87.60%
# Epoch: 994, Batch: 1, Loss: 0.299394, Accuracy: 87.06%
# Epoch: 994, Batch: 2, Loss: 0.287791, Accuracy: 87.40%
# Epoch: 994, Batch: 3, Loss: 0.295882, Accuracy: 87.60%
# Epoch: 994, Batch: 4, Loss: 0.291745, Accuracy: 87.74%
# Epoch: 994, Batch: 5, Loss: 0.290154, Accuracy: 87.26%
# Epoch: 994, Batch: 6, Loss: 0.298274, Accuracy: 86.72%
# Epoch: 994, Batch: 7, Loss: 0.299631, Accuracy: 87.55%
# Epoch: 994, Batch: 8, Loss: 0.294635, Accuracy: 87.70%
# Epoch: 994, Batch: 9, Loss: 0.301622, Accuracy: 87.35%
# Epoch: 994, Batch: 10, Loss: 0.300177, Accuracy: 86.91%
# Epoch: 994, Batch: 11, Loss: 0.301413, Accuracy: 88.13%
# Epoch: 994, Batch: 12, Loss: 0.292624, Accuracy: 87.50%
# Epoch: 994, Batch: 13, Loss: 0.293814, Accuracy: 87.21%
# Epoch: 994, Batch: 14, Loss: 0.295439, Accuracy: 87.21%
# Epoch: 994, Batch: 15, Loss: 0.279763, Accuracy: 88.57%
# Epoch: 994, Batch: 16, Loss: 0.297593, Accuracy: 86.96%
# Epoch: 994, Batch: 17, Loss: 0.292525, Accuracy: 88.23%
# Epoch: 994, Batch: 18, Loss: 0.280971, Accuracy: 88.43%
# Epoch: 994, Batch: 19, Loss: 0.282866, Accuracy: 88.38%
# Epoch: 994, Batch: 20, Loss: 0.300647, Accuracy: 87.50%
# Epoch: 994, Batch: 21, Loss: 0.277438, Accuracy: 89.01%
# Epoch: 994, Batch: 22, Loss: 0.282330, Accuracy: 87.99%
# Epoch: 994, Batch: 23, Loss: 0.267131, Accuracy: 89.84%
# Epoch: 994, Batch: 24, Loss: 0.317073, Accuracy: 86.87%
# Epoch: 994, Batch: 25, Loss: 0.285527, Accuracy: 87.65%
# Epoch: 994, Batch: 26, Loss: 0.296790, Accuracy: 87.84%
# Epoch: 994, Batch: 27, Loss: 0.117893, Accuracy: 32.91%
# Epoch: 994, Loss: 0.297459
# Epoch: 995, Batch: 0, Loss: 0.306948, Accuracy: 87.40%
# Epoch: 995, Batch: 1, Loss: 0.289297, Accuracy: 88.23%
# Epoch: 995, Batch: 2, Loss: 0.280455, Accuracy: 87.55%
# Epoch: 995, Batch: 3, Loss: 0.282350, Accuracy: 88.18%
# Epoch: 995, Batch: 4, Loss: 0.284326, Accuracy: 87.89%
# Epoch: 995, Batch: 5, Loss: 0.281279, Accuracy: 88.43%
# Epoch: 995, Batch: 6, Loss: 0.288215, Accuracy: 87.45%
# Epoch: 995, Batch: 7, Loss: 0.279930, Accuracy: 88.23%
# Epoch: 995, Batch: 8, Loss: 0.281125, Accuracy: 88.57%
# Epoch: 995, Batch: 9, Loss: 0.292893, Accuracy: 88.23%
# Epoch: 995, Batch: 10, Loss: 0.288132, Accuracy: 87.40%
# Epoch: 995, Batch: 11, Loss: 0.288965, Accuracy: 88.82%
# Epoch: 995, Batch: 12, Loss: 0.288750, Accuracy: 87.89%
# Epoch: 995, Batch: 13, Loss: 0.283020, Accuracy: 87.74%
# Epoch: 995, Batch: 14, Loss: 0.290038, Accuracy: 87.21%
# Epoch: 995, Batch: 15, Loss: 0.267208, Accuracy: 89.26%
# Epoch: 995, Batch: 16, Loss: 0.286996, Accuracy: 87.65%
# Epoch: 995, Batch: 17, Loss: 0.287034, Accuracy: 88.13%
# Epoch: 995, Batch: 18, Loss: 0.275616, Accuracy: 88.82%
# Epoch: 995, Batch: 19, Loss: 0.274017, Accuracy: 88.87%
# Epoch: 995, Batch: 20, Loss: 0.293488, Accuracy: 87.84%
# Epoch: 995, Batch: 21, Loss: 0.271088, Accuracy: 89.55%
# Epoch: 995, Batch: 22, Loss: 0.278602, Accuracy: 88.72%
# Epoch: 995, Batch: 23, Loss: 0.259652, Accuracy: 90.28%
# Epoch: 995, Batch: 24, Loss: 0.304162, Accuracy: 87.35%
# Epoch: 995, Batch: 25, Loss: 0.282305, Accuracy: 88.57%
# Epoch: 995, Batch: 26, Loss: 0.286593, Accuracy: 88.23%
# Epoch: 995, Batch: 27, Loss: 0.115400, Accuracy: 33.06%
# Epoch: 995, Loss: 0.288440
# Epoch: 996, Batch: 0, Loss: 0.298262, Accuracy: 87.89%
# Epoch: 996, Batch: 1, Loss: 0.283690, Accuracy: 88.92%
# Epoch: 996, Batch: 2, Loss: 0.276724, Accuracy: 88.38%
# Epoch: 996, Batch: 3, Loss: 0.279917, Accuracy: 88.72%
# Epoch: 996, Batch: 4, Loss: 0.277215, Accuracy: 88.67%
# Epoch: 996, Batch: 5, Loss: 0.273702, Accuracy: 88.57%
# Epoch: 996, Batch: 6, Loss: 0.284121, Accuracy: 87.65%
# Epoch: 996, Batch: 7, Loss: 0.280752, Accuracy: 88.87%
# Epoch: 996, Batch: 8, Loss: 0.275654, Accuracy: 88.82%
# Epoch: 996, Batch: 9, Loss: 0.286975, Accuracy: 88.62%
# Epoch: 996, Batch: 10, Loss: 0.284466, Accuracy: 87.70%
# Epoch: 996, Batch: 11, Loss: 0.287787, Accuracy: 88.96%
# Epoch: 996, Batch: 12, Loss: 0.283213, Accuracy: 88.33%
# Epoch: 996, Batch: 13, Loss: 0.278097, Accuracy: 88.18%
# Epoch: 996, Batch: 14, Loss: 0.283958, Accuracy: 87.40%
# Epoch: 996, Batch: 15, Loss: 0.266867, Accuracy: 89.31%
# Epoch: 996, Batch: 16, Loss: 0.283491, Accuracy: 87.89%
# Epoch: 996, Batch: 17, Loss: 0.280952, Accuracy: 88.38%
# Epoch: 996, Batch: 18, Loss: 0.268636, Accuracy: 88.77%
# Epoch: 996, Batch: 19, Loss: 0.271287, Accuracy: 89.16%
# Epoch: 996, Batch: 20, Loss: 0.289802, Accuracy: 88.04%
# Epoch: 996, Batch: 21, Loss: 0.265489, Accuracy: 89.94%
# Epoch: 996, Batch: 22, Loss: 0.274296, Accuracy: 88.23%
# Epoch: 996, Batch: 23, Loss: 0.261361, Accuracy: 90.04%
# Epoch: 996, Batch: 24, Loss: 0.299355, Accuracy: 87.99%
# Epoch: 996, Batch: 25, Loss: 0.276319, Accuracy: 88.48%
# Epoch: 996, Batch: 26, Loss: 0.283623, Accuracy: 88.62%
# Epoch: 996, Batch: 27, Loss: 0.113863, Accuracy: 33.20%
# Epoch: 996, Loss: 0.284069
# Epoch: 997, Batch: 0, Loss: 0.298125, Accuracy: 88.38%
# Epoch: 997, Batch: 1, Loss: 0.281552, Accuracy: 88.82%
# Epoch: 997, Batch: 2, Loss: 0.269380, Accuracy: 88.57%
# Epoch: 997, Batch: 3, Loss: 0.277602, Accuracy: 88.72%
# Epoch: 997, Batch: 4, Loss: 0.276792, Accuracy: 88.92%
# Epoch: 997, Batch: 5, Loss: 0.270480, Accuracy: 88.57%
# Epoch: 997, Batch: 6, Loss: 0.281976, Accuracy: 87.84%
# Epoch: 997, Batch: 7, Loss: 0.277441, Accuracy: 88.96%
# Epoch: 997, Batch: 8, Loss: 0.271270, Accuracy: 89.06%
# Epoch: 997, Batch: 9, Loss: 0.285604, Accuracy: 89.01%
# Epoch: 997, Batch: 10, Loss: 0.282016, Accuracy: 88.09%
# Epoch: 997, Batch: 11, Loss: 0.285733, Accuracy: 88.82%
# Epoch: 997, Batch: 12, Loss: 0.278775, Accuracy: 88.28%
# Epoch: 997, Batch: 13, Loss: 0.274547, Accuracy: 88.48%
# Epoch: 997, Batch: 14, Loss: 0.282510, Accuracy: 87.74%
# Epoch: 997, Batch: 15, Loss: 0.261578, Accuracy: 89.50%
# Epoch: 997, Batch: 16, Loss: 0.276445, Accuracy: 88.53%
# Epoch: 997, Batch: 17, Loss: 0.277957, Accuracy: 88.77%
# Epoch: 997, Batch: 18, Loss: 0.267897, Accuracy: 89.26%
# Epoch: 997, Batch: 19, Loss: 0.265756, Accuracy: 89.26%
# Epoch: 997, Batch: 20, Loss: 0.289699, Accuracy: 88.57%
# Epoch: 997, Batch: 21, Loss: 0.265526, Accuracy: 90.28%
# Epoch: 997, Batch: 22, Loss: 0.271630, Accuracy: 89.16%
# Epoch: 997, Batch: 23, Loss: 0.256478, Accuracy: 90.43%
# Epoch: 997, Batch: 24, Loss: 0.296919, Accuracy: 87.74%
# Epoch: 997, Batch: 25, Loss: 0.271457, Accuracy: 88.87%
# Epoch: 997, Batch: 26, Loss: 0.279611, Accuracy: 89.11%
# Epoch: 997, Batch: 27, Loss: 0.113033, Accuracy: 33.11%
# Epoch: 997, Loss: 0.281029
# Epoch: 998, Batch: 0, Loss: 0.290461, Accuracy: 88.13%
# Epoch: 998, Batch: 1, Loss: 0.274625, Accuracy: 89.26%
# Epoch: 998, Batch: 2, Loss: 0.264483, Accuracy: 89.26%
# Epoch: 998, Batch: 3, Loss: 0.276521, Accuracy: 88.87%
# Epoch: 998, Batch: 4, Loss: 0.272084, Accuracy: 88.92%
# Epoch: 998, Batch: 5, Loss: 0.268328, Accuracy: 88.57%
# Epoch: 998, Batch: 6, Loss: 0.277568, Accuracy: 88.23%
# Epoch: 998, Batch: 7, Loss: 0.272246, Accuracy: 89.11%
# Epoch: 998, Batch: 8, Loss: 0.267516, Accuracy: 89.26%
# Epoch: 998, Batch: 9, Loss: 0.279680, Accuracy: 88.87%
# Epoch: 998, Batch: 10, Loss: 0.276882, Accuracy: 88.43%
# Epoch: 998, Batch: 11, Loss: 0.279905, Accuracy: 89.01%
# Epoch: 998, Batch: 12, Loss: 0.276351, Accuracy: 88.72%
# Epoch: 998, Batch: 13, Loss: 0.272512, Accuracy: 88.38%
# Epoch: 998, Batch: 14, Loss: 0.279785, Accuracy: 87.60%
# Epoch: 998, Batch: 15, Loss: 0.258400, Accuracy: 90.19%
# Epoch: 998, Batch: 16, Loss: 0.275029, Accuracy: 88.43%
# Epoch: 998, Batch: 17, Loss: 0.277062, Accuracy: 88.72%
# Epoch: 998, Batch: 18, Loss: 0.265348, Accuracy: 88.72%
# Epoch: 998, Batch: 19, Loss: 0.263284, Accuracy: 89.70%
# Epoch: 998, Batch: 20, Loss: 0.284364, Accuracy: 88.67%
# Epoch: 998, Batch: 21, Loss: 0.262573, Accuracy: 90.33%
# Epoch: 998, Batch: 22, Loss: 0.266911, Accuracy: 89.26%
# Epoch: 998, Batch: 23, Loss: 0.254057, Accuracy: 90.82%
# Epoch: 998, Batch: 24, Loss: 0.294220, Accuracy: 87.94%
# Epoch: 998, Batch: 25, Loss: 0.272146, Accuracy: 88.67%
# Epoch: 998, Batch: 26, Loss: 0.279790, Accuracy: 88.77%
# Epoch: 998, Batch: 27, Loss: 0.112914, Accuracy: 33.11%
# Epoch: 998, Loss: 0.277594
# Epoch: 999, Batch: 0, Loss: 0.290470, Accuracy: 88.53%
# Epoch: 999, Batch: 1, Loss: 0.271382, Accuracy: 89.26%
# Epoch: 999, Batch: 2, Loss: 0.265013, Accuracy: 88.92%
# Epoch: 999, Batch: 3, Loss: 0.271251, Accuracy: 88.87%
# Epoch: 999, Batch: 4, Loss: 0.272591, Accuracy: 89.16%
# Epoch: 999, Batch: 5, Loss: 0.268173, Accuracy: 88.82%
# Epoch: 999, Batch: 6, Loss: 0.274675, Accuracy: 88.33%
# Epoch: 999, Batch: 7, Loss: 0.272764, Accuracy: 89.01%
# Epoch: 999, Batch: 8, Loss: 0.266556, Accuracy: 89.31%
# Epoch: 999, Batch: 9, Loss: 0.278967, Accuracy: 88.57%
# Epoch: 999, Batch: 10, Loss: 0.275568, Accuracy: 88.13%
# Epoch: 999, Batch: 11, Loss: 0.279063, Accuracy: 88.53%
# Epoch: 999, Batch: 12, Loss: 0.275701, Accuracy: 88.62%
# Epoch: 999, Batch: 13, Loss: 0.270667, Accuracy: 88.48%
# Epoch: 999, Batch: 14, Loss: 0.277333, Accuracy: 87.94%
# Epoch: 999, Batch: 15, Loss: 0.258409, Accuracy: 90.28%
# Epoch: 999, Batch: 16, Loss: 0.276024, Accuracy: 88.28%
# Epoch: 999, Batch: 17, Loss: 0.273822, Accuracy: 88.96%
# Epoch: 999, Batch: 18, Loss: 0.262924, Accuracy: 89.65%
# Epoch: 999, Batch: 19, Loss: 0.263070, Accuracy: 89.55%
# Epoch: 999, Batch: 20, Loss: 0.280724, Accuracy: 88.48%
# Epoch: 999, Batch: 21, Loss: 0.259179, Accuracy: 90.43%
# Epoch: 999, Batch: 22, Loss: 0.265541, Accuracy: 89.21%
# Epoch: 999, Batch: 23, Loss: 0.252629, Accuracy: 90.62%
# Epoch: 999, Batch: 24, Loss: 0.295493, Accuracy: 87.89%
# Epoch: 999, Batch: 25, Loss: 0.267719, Accuracy: 89.36%
# Epoch: 999, Batch: 26, Loss: 0.279490, Accuracy: 88.96%
# Epoch: 999, Batch: 27, Loss: 0.111826, Accuracy: 33.11%
# Epoch: 999, Loss: 0.276186

# %% [markdown]
# # Output Function

# %%
# Save the Model
torch.save(model.state_dict(), 'model_final.pth')

# %%
# Load the Model
model = EncDec(input_size, embedding_size, enc_hidden_size, encoding_size, dec_hidden_size, output_size, batch_size)
model.load_state_dict(torch.load('model_final.pth'))
# Out:
# <All keys matched successfully>

# %%
# Now, we need to run the model on the X_eval_numeric
# output = model(X_e[8].unsqueeze(0))
# output = output.squeeze(0)

# print(Y_eval_numeric[8])

# # Now, we need to get the output take the argmax of the output along the first dimension and convert it to a set of letters
# output = torch.argmax(output, dim = 1)
# print(output)

X_eval_numeric = []
X_eval_col = X_eval[:, 0]
Y_eval_col = X_eval[:, 1]
# Now, we need to convert the X_eval_col to numeric
X_eval_numeric, Y_eval_numeric = numericize(X_eval_col, Y_eval_col)
# Now, we need to convert the X_eval_numeric to a numpy array
X_eval_numeric = np.array(X_eval_numeric)
Y_eval_numeric = np.array(Y_eval_numeric)
# Now, we need to convert the X_eval_numeric to a tensor
X_eval_numeric = torch.from_numpy(X_eval_numeric)
Y_eval_numeric = torch.from_numpy(Y_eval_numeric)


output = model(X_numeric[7].unsqueeze(0))
output = output.squeeze(0)

print(Y_numeric[7])

output = torch.argmax(output, dim = 1)
print(output)
# Out:
# tensor([ 4, 21, 23, 21,  3, 22,  5, 20])
# tensor([17, 21, 23, 21,  3, 22,  5, 20])

# %%
def Model_Output(X):
    # Numerize the X
    X, _ = numericize(X, X)
    # Convert the X to a numpy array
    X = np.array(X)
    # Convert the X to a tensor
    X = torch.from_numpy(X)
    # Get the output from the model
    output = model(X)
    # Now, we need to get the output take the argmax of the output along the first dimension and convert it to a set of letters
    output = torch.argmax(output, dim = 2)
    # Now, we need to convert the output to a list of letters
    output = output.tolist()
    # Now, we need to convert the output to a list of letters
    output = [[chr(i + 97) for i in j] for j in output]
    # Join the letters in each list
    output = [''.join(i) for i in output]
    return output

def Model_Output_Single(x):
    # Numerize the X -> To get a list of numbers
    X, _ = numericize(x, x)
    # Convert the X to a numpy array
    X = np.array(X)
    # Convert the X to a tensor
    X = torch.from_numpy(X)
    X = X.squeeze(1)
    X = X.unsqueeze(0)
    # Get the output from the model
    output = model(X)
    # Now, we need to get the output take the argmax of the output along the first dimension and convert it to a set of letters
    output = torch.argmax(output, dim = 2)
    # Now, we need to convert the output to a list of letters
    output = output.tolist()
    # Now, we need to convert the output to a list of letters
    output = [[chr(i + 97) for i in j] for j in output]
    # Join the letters in each list
    output = [''.join(i) for i in output]
    return output

# Import the Test Dataset
test_dataset = pd.read_csv('eval_data.csv')
X_test = test_dataset.iloc[1:, :].values
X_test_col = X_test[:, 0]

output = Model_Output(X_test_col)
print(output)
print(X_test[:, 1].tolist())
# y_val = [chr(i + 97) for i in Y_eval_numeric]

# Find the Loss, between the output and the Y_eval_numeric
# loss = criterion(output, X_test[:, 1])
# Out:
# ['mfsoyhwl', 'xwjoqnkq', 'ndxjkzgb', 'qloqbgvx', 'swkibfor', 'hyasngvh', 'oatvtqyo', 'eccejgbt', 'fdtmtwhp', 'fdpdndyx', 'ojfyyzak', 'zdtfkduk', 'kvjghjlw', 'wksjvnky', 'pxqzjrmk', 'iynjeklv', 'efoarevr', 'btoovjhv', 'yebmjdjh', 'gnhyhjzi', 'ksytgpgt', 'gypzsfds', 'kwaimswj', 'eblbufds', 'rysqdjkb', 'prtmzsap', 'hrminzzp', 'vgcsnpxc', 'gcksonxm', 'xywzmpap', 'godhxdsj', 'drpdmglt', 'lwavfesu', 'hfjbjkge', 'awqtiryv', 'ebacftdx', 'zoprqthd', 'xrwgabkm', 'cvslxzfi', 'pwnbbarv', 'xlaoxqob', 'bzkshbvw', 'bffwlpyf', 'sthjqsdx', 'mxelgpsa', 'ktyjqequ', 'hyqvamgi', 'tbzgnaak', 'nlkghnmt', 'ochtchza', 'rhivnvai', 'aizyhosd', 'dmvuouzr', 'jaahbhjh', 'wgaxvvgc', 'vtuzflds', 'ngoitulc', 'hroqyanz', 'rjjardwf', 'hfxuapnb', 'pouxlhuh', 'zzsmvwjb', 'tetcxcmg', 'igdzsuyh', 'mgeywkck', 'jachnzeg', 'jmfirkmk', 'mxzcuebs', 'dpyljwfj', 'wcjtuhml', 'htbylrdl', 'hdofyxto', 'gwhrzhcm', 'gzoaomxd', 'xrxgepxg', 'hlyiasqt', 'vrlmirfm', 'efuomypc', 'ejfrjnqd', 'odsihvxy', 'cqwbtfke', 'fceckdvp', 'mdwkachv', 'bvjvvhaz', 'lgdlxben', 'aghypubp', 'ipunopxy', 'jctvsabx', 'vdhdxrjw', 'srehkqog', 'vjljivpn', 'pwukrcpw', 'vbxviqnu', 'wtzslnsa', 'ujsfttes', 'gaqaaezb', 'wfooxynj', 'eetskhwc', 'phowsbep', 'vvyebgrw', 'mzjbfuen', 'nhubkcmh', 'kzgsvugy', 'mblmcqxy', 'svewjtzd', 'lmnrsolq', 'qslcrwom', 'ldscfhdt', 'fbukxoat', 'czpyqiln', 'ocmhgebz', 'uktezjmk', 'ftayqlkf', 'rxjkxykj', 'argfdlxh', 'ojlbbkoe', 'nldigvbr', 'tptzlemn', 'fscbjblr', 'dgvgmxru', 'ignxuzlq', 'icyjtvwn', 'baazcpsa', 'mfvvrubu', 'gvtvmpkt', 'ddywdzal', 'xthnuawu', 'dprcadbg', 'lyxnyihk', 'oqonmwnz', 'cmecrdoe', 'jgxwqtzt', 'jojlvweb', 'penjupdb', 'vlmlfokl', 'pnsqdosk', 'bwskajdi', 'nbxbpavw', 'mjeplfsl', 'cembexak', 'zehxfuag', 'zuqdgwsm', 'pmoavsuo', 'vgmphvnm', 'mlskgxmv', 'gbbiodnw', 'ixeprcqp', 'zesbrlfv', 'bynlduol', 'fstpmiyk', 'xvegnaor', 'ynlugzhu', 'rbcpihti', 'bdnobsop', 'qvxonpba', 'bucoywef', 'cvlqrmto', 'qhupjich', 'wyaawzbo', 'pfnekbvh', 'udtnubfk', 'vwfozgpm', 'jkgnvrqt', 'opovmxms', 'phnldipc', 'nlijuhpm', 'gyvzsanl', 'xazejbvr', 'txiwcgte', 'gdvrvnti', 'wmwwpqmh', 'kwepbdcw', 'tsofduon', 'xqcgzoll', 'nkquzsue', 'nadcpdic', 'ejjkxzar', 'plerypfk', 'exoibynl', 'uuobqkhy', 'pbwzfxfw', 'qlldfyee', 'bgopgeyt', 'mfagnpyw', 'zghxwsxj', 'pxekqnax', 'odcodkyp', 'hsxxfivg', 'ddayvxwm', 'qhanaxoa', 'qpmrgxqn', 'bemfzudk', 'unmequan', 'cxyloqbb', 'llcrusvb', 'mdhsrpcu', 'ubjqgcrk', 'bdwewqit', 'ftpmpnof', 'vujxjong', 'juooaosk', 'tplqpwgt', 'snxywabu', 'vtvlnarj', 'mqsawxuw', 'ovzlvuct', 'hciveaei', 'ybpyeucj', 'mujbeaxk', 'ncmxwozz', 'thiexhgd', 'snasvcsw', 'jallmhgs', 'oizbmuns', 'zywgtyba', 'fmibntwl', 'vyssxcfv', 'vgpupsvx', 'mbneufhi', 'tcaicpry', 'bcjepclz', 'rryhqkig', 'ojzveubx', 'kokzkwjb', 'uhycfvvm', 'kvealdge', 'bjwuqtgy', 'xronrkkz', 'jcjamnqb', 'umgqjzsy', 'piqnnecb', 'kkpuicgd', 'csukpcgb', 'aclfwnws', 'xfjehnwf', 'uksdnlwc', 'mibvcsep', 'dwgwmqkq', 'avngikje', 'nsvzhdbf', 'pzqzikgj', 'gdzgonru', 'ksgeldxl', 'xkqqafij', 'shafqqsu', 'zrfzqwfk', 'guhnkewg', 'cwqklrao', 'jgyoifdj', 'lerizqcw', 'qdoumhrm', 'egmavzoo', 'durpdvzm', 'jlvhpxwy', 'xbkshxpd', 'dyamrfya', 'ippvppxe', 'oosgybyi', 'sbpzldcx', 'eotqoozc', 'dyqpgpqr', 'ziwwcqxr', 'beaeosqb', 'wsodoogx', 'lfdbuofv', 'nahmcuun', 'lyiumsmv', 'udtagpqw', 'xrokkwwn', 'bgkzexod', 'raacuvtb', 'mqiujuvo', 'lvgtutnm', 'uqytanbo', 'sgpkvsog', 'gxxqbjvt', 'jvpardnb', 'rucommua', 'jfdmfdkf', 'jbonxrga', 'vsaugsfu', 'tgrgjyuk', 'eajwdswr', 'boualekc', 'fpzbdijr', 'jcwgtidy', 'cfxwwfih', 'wbgvfknl', 'zbirtgub', 'fjhoyhrx', 'zdpkueml', 'tvylblpe', 'arkktuyr', 'ancivxyn', 'eyssutbk', 'uqiziion', 'wdiwkrji', 'mwhxgxgf', 'dwrkbcng', 'hkmlpxic', 'oswkxlgz', 'vjxsyjkd', 'ymgqtnst', 'ycgueqwe', 'uikzsian', 'xbqdckro', 'bfisrgsm', 'euaxbutk', 'rvpqgpdx', 'wjxrhdwh', 'qezajgiq', 'jiaeffom', 'vynuyace', 'yeolsang', 'hgjnbsfh', 'lrrqomzp', 'vshfxqbk', 'vsdrzjrq', 'ebokfigw', 'oalfukcs', 'pquesigw', 'ajjakiwv', 'mzgkgnvv', 'upqcexxl', 'alcjmltg', 'zitzhnai', 'ttxikphc', 'ssxmhdnp', 'ymvborgk', 'aitzmtsa', 'nksmoedp', 'aaohanyo', 'rcvwtgof', 'zi ...
# ['mffolhhl', 'xjwbqnnq', 'nqxwxmtb', 'dlbdbgvx', 'fwkibsou', 'ulafntih', 'ontitdlb', 'epprjfot', 'sdgztwup', 'sqcdadyx', 'ojsllopa', 'zdtsndhk', 'kiwtuwyj', 'jxfwiaky', 'cxqzjrox', 'vyakrkdv', 'rfoaeevr', 'bgbcvwei', 'yrozhdru', 'gnulhwmv', 'kflttcgt', 'tlcmfsqf', 'kwnizswj', 'ebyojfqs', 'eyfqqwxb', 'prgzmfap', 'urmvnzmp', 'itpsafkp', 'gpksonaz', 'xyhzjnnc', 'toqhxqfm', 'qepqztyt', 'yjnifefh', 'usjbjkge', 'njdgirlv', 'roapftdm', 'mbceqtud', 'xewtalxz', 'pifykzti', 'pjnobapi', 'xyabkdzb', 'bzksupiw', 'bfsjlqks', 'fthjqsqz', 'mkelgcfa', 'xgljdrqh', 'ulqiamgx', 'tbotnnnx', 'ayxthnwg', 'ocutpuma', 'ruiunvnv', 'nvmyhofq', 'dmihohme', 'jnnhbhwu', 'jgnkvigc', 'vthmsydf', 'agoighyc', 'urodyanz', 'ewjnedwf', 'ufkhapao', 'pohxluuh', 'mzfmihwb', 'grtqxpkg', 'ihqzfuyh', 'mtrijxpx', 'jacunzrt', 'jmsibxzx', 'zxmouros', 'qcylwjij', 'jcjguuml', 'htoylrdy', 'hdbsyxgo', 'twhrzhpo', 'tzozbzkq', 'xektrpxg', 'uylvafqt', 'ielmvefm', 'eshozycp', 'rwsrjndq', 'bqfvtvxy', 'pdjbtfke', 'fcecxdvp', 'zdykapht', 'bvziihmm', 'ytdykoen', 'athycupc', 'iptnopxl', 'jptifnpk', 'vdhsxrwj', 'seefipbg', 'vjlwvipa', 'cjukedpm', 'ibkkidaj', 'jgmslnfn', 'hjsfgtef', 'tndaarzp', 'jsooxfnj', 'regsxhwc', 'chbwfbec', 'ivlrotew', 'zmjofhrn', 'ahhbkcph', 'kmgsiuey', 'zoyzpdal', 'fvejjgmq', 'lzarfold', 'dfyppwom', 'lqfnfude', 'sohvxbag', 'cmpldiln', 'bczttemb', 'hxtrzjmk', 'srnldykf', 'exjxkykw', 'negfdyxu', 'ojlooxle', 'aydfgvcj', 'gctmyezn', 'ffbbwble', 'qtvtmkbh', 'vgnkumyd', 'vplwtikn', 'banzppfc', 'mfviehch', 'gitizcxg', 'ddywdmal', 'xggnwnus', 'qcroadog', 'llxpluuk', 'oqonzwpz', 'pmecrdoe', 'jgxjqgmg', 'jojlvweb', 'penwupbo', 'iymlgbkl', 'cnfsqbfk', 'bwfxajdv', 'aoxbcnhw', 'mjepyffl', 'pembeknx', 'mehxshat', 'zuqctwsm', 'pmbnxsub', 'vgmphiaz', 'mlsxgxzf', 'toovedaw', 'ikececqc', 'zrsbrlfv', 'oyayqhoy', 'sstpmimx', 'xiegnnzr', 'ynyhgmhh', 'roppiugi', 'bqnooszc', 'qikonpop', 'oucblwms', 'pvldrmgo', 'qhhpwvlh', 'jlnnlmbb', 'pfarkofu', 'udgahosk', 'vjfbzgpz', 'wkgajrdg', 'ocbvmkmf', 'cuclqvcp', 'nyiyuupm', 'glimsaal', 'knmewove', 'txvwptte', 'tqirvati', 'wmjwcpzh', 'kwrpoqcj', 'tfosqgpn', 'kqptzoll', 'nxduzfje', 'nnqpbdvp', 'ewwxabar', 'clerycsk', 'ekbvolny', 'uhoodxhl', 'powpfyfw', 'qylqsyee', 'otbctryg', 'zsagnplj', 'zthxjsxj', 'pkrkdsnx', 'oqpoqklp', 'ufkksiit', 'ddnlikhm', 'dvannxea', 'qcmrtxdp', 'oemfzuqk', 'uazeqhaa', 'pkylrqob', 'yyprjsvb', 'mdusrccu', 'hojdgcem', 'oqjewdig', 'ftpmcaos', 'ihwxjbat', 'whboabsx', 'tclqchgh', 'fnkyjnbu', 'vtiyalrh', 'zqfnwxuw', 'bimyiumt', 'hciienev', 'locleucw', 'zujbenlx', 'npzkwomm', 'ghlekttq', 'fnnsicsw', 'wnyyzugs', 'oizbmuns', 'mlwgtyoa', 'fmioctjk', 'iysfxcfv', 'itpwcfkx', 'zoneushi', 'tcavccrl', 'bpweppyz', 'eelrdxvj', 'bwzirhok', 'xokmkjjo', 'hhlpfvim', 'xirnydrr', 'ojwhdghy', 'kronoxxz', 'wpuxzacb', 'hztdwmsl', 'pidaarqb', 'xxcuiqgq', 'cfhxcbgo', 'ncyfjajs', 'xfwehawf', 'hkfdnnup', 'miovptrp', 'djgwzdlq', 'nintiujr', 'afvmhdos', 'czqmvxgw', 'gqztpnrh', 'kftrlqxy', 'kxddnfvw', 'fhasqdsu', 'meszqwhk', 'guhnxejt', 'cjqxleal', 'jtybicpw', 'lrrizqpw', 'qqohzuem', 'rgznvmob', 'duepdvmz', 'jliucxjl', 'xoxfhkcd', 'dynmrsyc', 'vppiqaye', 'bofglosi', 'fbqzyqcx', 'rbgdoomp', 'dyqctpqe', 'ziwjcqxr', 'oeaeysnb', 'wsbqobgk', 'lfqbubsj', 'aaumcuua', 'yyihzpkk', 'hqtntcfw', 'keokvwwn', 'btkzrkbd', 'eaapuvgb', 'zdvwwhgy', 'lvgdugaz', 'hqlgnzoo', 'fhckisbt', 'gxxqpjht', 'whppeqnb', 'rupbzmha', 'wfqzsdxf', 'jbbaxrta', 'vfnugfsu', 'gtrtjlux', 'eajwgsjr', 'obualrxp', 'fcmoqvwr', 'jcjtgvdl', 'pfxjwfvs', 'jbgvhkcy', 'zovegtup', 'swhbnhek', 'zdpkxrzy', 'gillbyce', 'nrxxghyr', 'aapvviya', 'ryffugok', 'uqvziion', 'wdijxeji', 'mwuxtxtf', 'qjeiooat', 'hxmlpkyc', 'oswkvyrm', 'vjxflwxd', 'lmtdtnfy', 'lcgueqwr', 'uvxzsuaa', 'kodqpkeb', 'bsisegsz', 'ehnkougx', 'rvcqgcdx', 'wwkruduh', 'delawgid', 'winesfbz', 'ilnhynpr', 'lrclfapt', 'ugjaossu', 'lrrdezmp', 'ishsxdox', 'isqrzjoq', 'rookfihj', 'oalfhkpf', 'pdhesvgw', 'awjaxvwv', 'mztkgnhk', 'upqcevkl', 'nypwmkyt', 'mitcuanv', 'tgkvxnup', 'ffklhdmc', 'yzveorgx', 'avtzmgsa', 'akfzordc', 'nnotaalo', 'epvjgtbf', 'mi ...

# %% [markdown]
# ## Checker Script

# %%
import pandas as pd
import numpy as np

# Function to check how many characters match in the two strings
def check(pred: str, true: str):
    correct = 0
    for a, b in zip(pred, true):
        if a == b:
            correct += 1

    # Prediction is more than 8 letters, so penalize for every extra letter.
    correct -= max(0, len(pred) - len(true))
    correct = max(0, correct)
    return correct

# Function to score the model's performance
def evaluate(model):
    # Train data
    print("Obtaining results for training data:")
    train_data = pd.read_csv("train_data.csv").to_numpy()
    results = {
        "pred": [],
        "true": [],
        "score": [],
    }
    count = 0
    correct = [0 for _ in range(9)]
    for x, y in train_data:
        pred = Model_Output_Single(x)
        pred = ''.join(pred)
        score = check(pred, y)
        results["pred"].append(pred)
        results["true"].append(y)
        results["score"].append(score)

        correct[score] += 1
        count += 1
    print("Train dataset results:")
    for num_chr in range(9):
        print(
            f"Number of predictions with {num_chr} correct predictions: {correct[num_chr]}"
        )
    points = sum(correct[4:6]) * 0.5 + sum(correct[6:])
    print(f"Points: {points}")
    # Save predicitons and true sentences to inspect manually if required.
    pd.DataFrame.from_dict(results).to_csv("results_train.csv", index=False)

    #----------------------------------------------------------------------------------

    print("Obtaining metrics for eval data:")
    count = 0
    eval_data = pd.read_csv("eval_data.csv").to_numpy()
    results = {
        "pred": [],
        "true": [],
        "score": [],
    }
    correct = [0 for _ in range(9)]
    for x, y in eval_data:
        pred = Model_Output_Single(x)
        pred = ''.join(pred)
        score = check(pred, y)
        results["pred"].append(pred)
        results["true"].append(y)
        results["score"].append(score)
        correct[score] += 1
    print("Eval dataset results:")
    for num_chr in range(9):
        print(
            f"Number of predictions with {num_chr} correct predictions: {correct[num_chr]}"
        )
    points = sum(correct[4:6]) * 0.5 + sum(correct[6:])
    marks = round(min(2, points / 1400 * 2) * 2) / 2  # Rounds to the nearest 0.5
    print(f"Points: {points}")
    print(f"Marks: {marks}")
    # Save predicitons and true sentences to inspect manually if required.
    pd.DataFrame.from_dict(results).to_csv("results_eval.csv", index=False)

evaluate(model)
# Out:
# Obtaining results for training data:
# Train dataset results:
# Number of predictions with 0 correct predictions: 0
# Number of predictions with 1 correct predictions: 0
# Number of predictions with 2 correct predictions: 0
# Number of predictions with 3 correct predictions: 0
# Number of predictions with 4 correct predictions: 17
# Number of predictions with 5 correct predictions: 232
# Number of predictions with 6 correct predictions: 1304
# Number of predictions with 7 correct predictions: 2973
# Number of predictions with 8 correct predictions: 2474
# Points: 6875.5
# Obtaining metrics for eval data:
# Eval dataset results:
# Number of predictions with 0 correct predictions: 15
# Number of predictions with 1 correct predictions: 99
# Number of predictions with 2 correct predictions: 273
# Number of predictions with 3 correct predictions: 499
# Number of predictions with 4 correct predictions: 529
# Number of predictions with 5 correct predictions: 397
# Number of predictions with 6 correct predictions: 149
# Number of predictions with 7 correct predictions: 36
# Number of predictions with 8 correct predictions: 3
# Points: 651.0
# Marks: 1.0
# wandb: Network error (ConnectionError), entering retry loop.
